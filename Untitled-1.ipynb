# %%
from IPython import get_ipython
get_ipython().run_line_magic('reset', '-sf') 

import psycopg2
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import glob
import re

# %%
def file_extraction(search_string): 
    filepaths = glob.glob(search_string) 
    df = pd.DataFrame()
    for find_files in filepaths:
        param = re.split ('_',find_files)
        add_df = pd.read_excel(find_files, usecols=[2,5])
        add_df ['animal_num'] = param [0][-1]  
        add_df ['exp_group'] = param [3]
        add_df ['cell_num'] =param [2][-1] 
        add_df ['protein'] = param[-1][:-5]
        df = pd.concat ([df, add_df], ignore_index=True)
    return(df)

# %% [markdown]
# Grab data and transform it into a Pandas dataftame

# %%
def idx_column_rename(change_df):
    change_df.index.names = ['id'] 
    change_df.rename(columns={'Volume (unit)':'volume', 'SurfaceArea':'surface_area'}, inplace=True)
    return change_df

# %%
df_gfap = file_extraction('data/*GFAP.xlsx')
df_gfap = idx_column_rename(df_gfap)

df_gs = file_extraction('data/*GS.xlsx')
df_gs = idx_column_rename(df_gs)

df_glt = file_extraction('data/*GLT.xlsx')
df_glt = idx_column_rename(df_glt)

df_s100b = file_extraction('data/*s100b.xlsx')
df_s100b = idx_column_rename(df_s100b)

df_cx43 = file_extraction('data/*Cx43.xlsx')
df_cx43 = idx_column_rename(df_cx43)

# %% [markdown]
# Connect to an existing database. It seems that sqlalchemy is needed as an intermediary in order to export a dataframe to a database.

# %%
#conn = psycopg2.connect("dbname=epi_data user=postgres password=123")
#localhost:5432:postgres:postgres:123
conn = create_engine('postgresql+psycopg2://postgres:123@localhost:5432/epi_data')
#conn = conn.execution_options(postgresql_readonly=False, postgresql_deferrable=True)
print(conn)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/epi_data)

# %%
df_gfap.to_sql('gfap', conn, schema='demo_schema', if_exists='append')
df_gs.to_sql('gs', conn, schema='demo_schema', if_exists='append')
df_glt.to_sql('glt', conn, schema='demo_schema', if_exists='append')
df_s100b.to_sql('s100b', conn, schema='demo_schema', if_exists='append')
df_cx43.to_sql('cx43', conn, schema='demo_schema', if_exists='append')

# %%
conn.execute('SELECT * FROM glt').fetchall()
# Out:
# [(0, Decimal('0.0788'), Decimal('1.4307'), 1, 'ctrl', 1, 'GLT'),
#  (1, Decimal('0.1504'), Decimal('2.5328'), 1, 'ctrl', 1, 'GLT'),
#  (2, Decimal('0.3366'), Decimal('3.3982'), 1, 'ctrl', 1, 'GLT'),
#  (3, Decimal('0.2685'), Decimal('3.8858'), 1, 'ctrl', 1, 'GLT'),
#  (4, Decimal('0.4296'), Decimal('5.0187'), 1, 'ctrl', 1, 'GLT'),
#  (5, Decimal('0.0967'), Decimal('1.6212'), 1, 'ctrl', 1, 'GLT'),
#  (6, Decimal('0.1217'), Decimal('1.985'), 1, 'ctrl', 1, 'GLT'),
#  (7, Decimal('0.1074'), Decimal('2.0562'), 1, 'ctrl', 1, 'GLT'),
#  (8, Decimal('0.0251'), Decimal('0.602'), 1, 'ctrl', 1, 'GLT'),
#  (9, Decimal('0.154'), Decimal('2.1399'), 1, 'ctrl', 1, 'GLT'),
#  (10, Decimal('0.2542'), Decimal('3.743'), 1, 'ctrl', 1, 'GLT'),
#  (11, Decimal('0.3366'), Decimal('3.8567'), 1, 'ctrl', 1, 'GLT'),
#  (12, Decimal('0.2578'), Decimal('3.1235'), 1, 'ctrl', 1, 'GLT'),
#  (13, Decimal('0.3115'), Decimal('3.9817'), 1, 'ctrl', 1, 'GLT'),
#  (14, Decimal('0.2291'), Decimal('2.9151'), 1, 'ctrl', 1, 'GLT'),
#  (15, Decimal('0.3831'), Decimal('4.2503'), 1, 'ctrl', 1, 'GLT'),
#  (16, Decimal('0.3366'), Decimal('4.2018'), 1, 'ctrl', 1, 'GLT'),
#  (17, Decimal('0.0931'), Decimal('1.5439'), 1, 'ctrl', 1, 'GLT'),
#  (18, Decimal('0.4117'), Decimal('4.4167'), 1, 'ctrl', 1, 'GLT'),
#  (19, Decimal('0.2828'), Decimal('3.6657'), 1, 'ctrl', 1, 'GLT'),
#  (20, Decimal('0.4905'), Decimal('5.484'), 1, 'ctrl', 1, 'GLT'),
#  (21, Decimal('0.1504'), Decimal('2.1399'), 1, 'ctrl', 1, 'GLT'),
#  (22, Decimal('0.3724'), Decimal('4.5186'), 1, 'ctrl', 1, 'GLT'),
#  (23, Decimal('0.0895'), Decimal('1.6273'), 1, 'ctrl', 1, 'GLT'),
#  (24, Decimal('0.1719'), Decimal('2.1104'), 1, 'ctrl', 1, 'GLT'),
#  (25, Decimal('0.469'), Decimal('4.8338'), 1, 'ctrl', 1, 'GLT'),
#  (26, Decimal('0.6695'), Decimal('6.1815'), 1, 'ctrl', 1, 'GLT'),
#  (27, Decimal('0.4726'), Decimal('4.6375'), 1, 'ctrl', 1, 'GLT'),
#  (28, Decimal('0.3151'), Decimal('4.0412'), 1, 'ctrl', 1, 'GLT'),
#  (29, Decimal('0.3079'), Decimal('3.3501'), 1, 'ctrl', 1, 'GLT'),
#  (30, Decimal('0.3724'), Decimal('3.9938'), 1, 'ctrl', 1, 'GLT'),
#  (31, Decimal('0.4332'), Decimal('4.0237'), 1, 'ctrl', 1, 'GLT'),
#  (32, Decimal('0.1146'), Decimal('1.9494'), 1, 'ctrl', 1, 'GLT'),
#  (33, Decimal('0.333'), Decimal('3.9521'), 1, 'ctrl', 1, 'GLT'),
#  (34, Decimal('0.1898'), Decimal('2.992'), 1, 'ctrl', 1, 'GLT'),
#  (35, Decimal('0.58'), Decimal('5.7048'), 1, 'ctrl', 1, 'GLT'),
#  (36, Decimal('0.2864'), Decimal('3.66'), 1, 'ctrl', 1, 'GLT'),
#  (37, Decimal('0.154'), Decimal('2.3188'), 1, 'ctrl', 1, 'GLT'),
#  (38, Decimal('0.1719'), Decimal('2.4616'), 1, 'ctrl', 1, 'GLT'),
#  (39, Decimal('0.3759'), Decimal('4.411'), 1, 'ctrl', 1, 'GLT'),
#  (40, Decimal('0.2327'), Decimal('2.9269'), 1, 'ctrl', 1, 'GLT'),
#  (41, Decimal('0.1361'), Decimal('2.1994'), 1, 'ctrl', 1, 'GLT'),
#  (42, Decimal('0.3008'), Decimal('3.6896'), 1, 'ctrl', 1, 'GLT'),
#  (43, Decimal('0.3724'), Decimal('4.4053'), 1, 'ctrl', 1, 'GLT'),
#  (44, Decimal('0.4547'), Decimal('4.2208'), 1, 'ctrl', 1, 'GLT'),
#  (45, Decimal('0.3437'), Decimal('3.8923'), 1, 'ctrl', 1, 'GLT'),
#  (46, Decimal('0.3187'), Decimal('3.6123'), 1, 'ctrl', 1, 'GLT'),
#  (47, Decimal('0.1396'), Decimal('1.9194'), 1, 'ctrl', 1, 'GLT'),
#  (48, Decimal('0.4834'), Decimal('5.4237'), 1, 'ctrl', 1, 'GLT'),
#  (49, Decimal('0.3652'), Decimal('4.059'), 1, 'ctrl', 1, 'GLT'),
#  (50, Decimal('0.2542'), Decimal('3.1413'), 1, 'ctrl', 1, 'GLT'),
#  (51, Decimal('0.3437'), Decimal('3.7915'), 1, 'ctrl', 1, 'GLT'),
#  (52, Decimal('0.3831'), Decimal('3.9938'), 1, 'ctrl', 1, 'GLT'),
#  (53, Decimal('0.3688'), Decimal('4.2382'), 1, 'ctrl', 1, 'GLT'),
#  (54, Decimal('0.3688'), Decimal('4.6372'), 1, 'ctrl', 1, 'GLT'),
#  (55, Decimal('0.2077'), Decimal('3.2069'), 1, 'ctrl', 1, 'GLT'),
#  (56, Decimal('0.2685'), Decimal('2.903'), 1, 'ctrl', 1, 'GLT'),
#  (57, Decimal('0.0609'), Decimal('1.0908'), 1, 'ctrl', 1, 'GLT'),
#  (58, Decimal('0.0179'), Decimal('0.5304'), 1, 'ctrl', 1, 'GLT'),
#  (59, Decimal('0.5048'), Decimal('5.168'), 1, 'ctrl', 1, 'GLT'),
#  (60, Decimal('0.4225'), Decimal('4.0711'), 1, 'ctrl', 1, 'GLT'),
#  (61, Decimal('0.2327'), Decimal('3.0163'), 1, 'ctrl', 1, 'GLT'),
#  (62, Decimal('0.2864'), Decimal('3.904'), 1, 'ctrl', 1, 'GLT'),
#  (63, Decimal('0.1074'), Decimal('1.7107'), 1, 'ctrl', 1, 'GLT'),
#  (64, Decimal('0.4905'), Decimal('5.0013'), 1, 'ctrl', 1, 'GLT'),
#  (65, Decimal('0.1862'), Decimal('2.5154'), 1, 'ctrl', 1, 'GLT'),
#  (66, Decimal('0.4654'), Decimal('4.5061'), 1, 'ctrl', 1, 'GLT'),
#  (67, Decimal('0.5013'), Decimal('5.0365'), 1, 'ctrl', 1, 'GLT'),
#  (68, Decimal('0.6122'), Decimal('5.6689'), 1, 'ctrl', 1, 'GLT'),
#  (69, Decimal('0.3151'), Decimal('3.3141'), 1, 'ctrl', 1, 'GLT'),
#  (70, Decimal('0.0788'), Decimal('1.4129'), 1, 'ctrl', 1, 'GLT'),
#  (71, Decimal('0.3258'), Decimal('3.7968'), 1, 'ctrl', 1, 'GLT'),
#  (72, Decimal('0.1683'), Decimal('2.2892'), 1, 'ctrl', 1, 'GLT'),
#  (73, Decimal('0.3867'), Decimal('4.0059'), 1, 'ctrl', 1, 'GLT'),
#  (74, Decimal('0.2327'), Decimal('2.742'), 1, 'ctrl', 1, 'GLT'),
#  (75, Decimal('0.4225'), Decimal('4.0059'), 1, 'ctrl', 1, 'GLT'),
#  (76, Decimal('0.2828'), Decimal('3.3736'), 1, 'ctrl', 1, 'GLT'),
#  (77, Decimal('0.4153'), Decimal('4.22'), 1, 'ctrl', 1, 'GLT'),
#  (78, Decimal('0.5693'), Decimal('5.1028'), 1, 'ctrl', 1, 'GLT'),
#  (79, Decimal('0.4511'), Decimal('4.1257'), 1, 'ctrl', 1, 'GLT'),
#  (80, Decimal('0.3867'), Decimal('4.3094'), 1, 'ctrl', 1, 'GLT'),
#  (81, Decimal('0.2757'), Decimal('3.5706'), 1, 'ctrl', 1, 'GLT'),
#  (82, Decimal('0.2721'), Decimal('3.1299'), 1, 'ctrl', 1, 'GLT'),
#  (83, Decimal('0.1862'), Decimal('2.7776'), 1, 'ctrl', 1, 'GLT'),
#  (84, Decimal('0.1647'), Decimal('2.307'), 1, 'ctrl', 1, 'GLT'),
#  (85, Decimal('0.1898'), Decimal('2.5631'), 1, 'ctrl', 1, 'GLT'),
#  (86, Decimal('0.3867'), Decimal('4.3988'), 1, 'ctrl', 1, 'GLT'),
#  (87, Decimal('0.5836'), Decimal('5.8534'), 1, 'ctrl', 1, 'GLT'),
#  (88, Decimal('0.5048'), Decimal('5.0426'), 1, 'ctrl', 1, 'GLT'),
#  (89, Decimal('0.3366'), Decimal('3.9105'), 1, 'ctrl', 1, 'GLT'),
#  (90, Decimal('0.2148'), Decimal('2.7658'), 1, 'ctrl', 1, 'GLT'),
#  (91, Decimal('0.2542'), Decimal('2.9803'), 1, 'ctrl', 1, 'GLT'),
#  (92, Decimal('0.4726'), Decimal('4.9774'), 1, 'ctrl', 1, 'GLT'),
#  (93, Decimal('0.3258'), Decimal('3.7434'), 1, 'ctrl', 1, 'GLT'),
#  (94, Decimal('0.4475'), Decimal('4.6792'), 1, 'ctrl', 1, 'GLT'),
#  (95, Decimal('0.6301'), Decimal('6.1091'), 1, 'ctrl', 1, 'GLT'),
#  (96, Decimal('0.444'), Decimal('5.0967'), 1, 'ctrl', 1, 'GLT'),
#  (97, Decimal('0.1647'), Decimal('2.1816'), 1, 'ctrl', 1, 'GLT'),
#  (98, Decimal('0.1432'), Decimal('2.1998'), 1, 'ctrl', 1, 'GLT'),
#  (99, Decimal('0.2542'), Decimal('3.1175'), 1, 'ctrl', 1, 'GLT'),
#  (100, Decimal('0.3688'), Decimal('4.3337'), 1, 'ctrl', 1, 'GLT'),
#  (101, Decimal('0.6874'), Decimal('5.7821'), 1, 'ctrl', 1, 'GLT'),
#  (102, Decimal('0.2256'), Decimal('2.9625'), 1, 'ctrl', 1, 'GLT'),
#  (103, Decimal('0.2041'), Decimal('2.6052'), 1, 'ctrl', 1, 'GLT'),
#  (104, Decimal('0.7304'), Decimal('6.4372'), 1, 'ctrl', 1, 'GLT'),
#  (105, Decimal('0.0716'), Decimal('1.478'), 1, 'ctrl', 1, 'GLT'),
#  (106, Decimal('0.4511'), Decimal('3.8635'), 1, 'ctrl', 1, 'GLT'),
#  (107, Decimal('0.3151'), Decimal('3.4278'), 1, 'ctrl', 1, 'GLT'),
#  (108, Decimal('0.4619'), Decimal('4.0775'), 1, 'ctrl', 1, 'GLT'),
#  (109, Decimal('0.3222'), Decimal('3.7616'), 1, 'ctrl', 1, 'GLT'),
#  (110, Decimal('0.1826'), Decimal('2.3665'), 1, 'ctrl', 1, 'GLT'),
#  (111, Decimal('0.5013'), Decimal('4.3219'), 1, 'ctrl', 1, 'GLT'),
#  (112, Decimal('0.6194'), Decimal('5.7105'), 1, 'ctrl', 1, 'GLT'),
#  (113, Decimal('0.3473'), Decimal('3.6005'), 1, 'ctrl', 1, 'GLT'),
#  (114, Decimal('0.2864'), Decimal('3.3618'), 1, 'ctrl', 1, 'GLT'),
#  (115, Decimal('0.154'), Decimal('2.1577'), 1, 'ctrl', 1, 'GLT'),
#  (116, Decimal('0.154'), Decimal('1.9494'), 1, 'ctrl', 1, 'GLT'),
#  (117, Decimal('0.0107'), Decimal('0.3338'), 1, 'ctrl', 1, 'GLT'),
#  (118, Decimal('0.358'), Decimal('4.3034'), 1, 'ctrl', 1, 'GLT'),
#  (119, Decimal('0.1003'), Decimal('1.7584'), 1, 'ctrl', 1, 'GLT'),
#  (120, Decimal('0.1898'), Decimal('2.4976'), 1, 'ctrl', 1, 'GLT'),
#  (121, Decimal('0.2148'), Decimal('2.4025'), 1, 'ctrl', 1, 'GLT'),
#  (122, Decimal('0.179'), Decimal('2.5631'), 1, 'ctrl', 1, 'GLT'),
#  (123, Decimal('0.1575'), Decimal('2.0861'), 1, 'ctrl', 1, 'GLT'),
#  (124, Decimal('0.2148'), Decimal('3.308'), 1, 'ctrl', 1, 'GLT'),
#  (125, Decimal('1.6255'), Decimal('11.0979'), 1, 'ctrl', 1, 'GLT'),
#  (126, Decimal('0.333'), Decimal('3.3918'), 1, 'ctrl', 1, 'GLT'),
#  (127, Decimal('0.2972'), Decimal('3.183'), 1, 'ctrl', 1, 'GLT'),
#  (128, Decimal('0.2184'), Decimal('2.8075'), 1, 'ctrl', 1, 'GLT'),
#  (129, Decimal('0.3724'), Decimal('3.7437'), 1, 'ctrl', 1, 'GLT'),
#  (130, Decimal('0.2184'), Decimal('3.308'), 1, 'ctrl', 1, 'GLT'),
#  (131, Decimal('0.1754'), Decimal('2.182'), 1, 'ctrl', 1, 'GLT'),
#  (132, Decimal('0.2864'), Decimal('3.4217'), 1, 'ctrl', 1, 'GLT'),
#  (133, Decimal('0.3938'), Decimal('4.6254'), 1, 'ctrl', 1, 'GLT'),
#  (134, Decimal('0.4869'), Decimal('5.1024'), 1, 'ctrl', 1, 'GLT'),
#  (135, Decimal('0.4475'), Decimal('4.4826'), 1, 'ctrl', 1, 'GLT'),
#  (136, Decimal('0.2256'), Decimal('2.748'), 1, 'ctrl', 1, 'GLT'),
#  (137, Decimal('0.333'), Decimal('4.0116'), 1, 'ctrl', 1, 'GLT'),
#  (138, Decimal('0.691'), Decimal('6.9737'), 1, 'ctrl', 1, 'GLT'),
#  (139, Decimal('0.222'), Decimal('2.6465'), 1, 'ctrl', 1, 'GLT'),
#  (140, Decimal('0.1647'), Decimal('2.1221'), 1, 'ctrl', 1, 'GLT'),
#  (141, Decimal('0.2542'), Decimal('2.9148'), 1, 'ctrl', 1, 'GLT'),
#  (142, Decimal('0.4762'), Decimal('4.9713'), 1, 'ctrl', 1, 'GLT'),
#  (143, Decimal('0.2828'), Decimal('3.4452'), 1, 'ctrl', 1, 'GLT'),
#  (144, Decimal('0.2399'), Decimal('2.9447'), 1, 'ctrl', 1, 'GLT'),
#  (145, Decimal('0.2184'), Decimal('3.0697'), 1, 'ctrl', 1, 'GLT'),
#  (146, Decimal('0.1146'), Decimal('1.83'), 1, 'ctrl', 1, 'GLT'),
#  (147, Decimal('0.1719'), Decimal('2.4321'), 1, 'ctrl', 1, 'GLT'),
#  (148, Decimal('0.2649'), Decimal('3.5702'), 1, 'ctrl', 1, 'GLT'),
#  (149, Decimal('0.6552'), Decimal('6.0682'), 1, 'ctrl', 1, 'GLT'),
#  (150, Decimal('0.4619'), Decimal('4.9293'), 1, 'ctrl', 1, 'GLT'),
#  (151, Decimal('0.1003'), Decimal('1.5678'), 1, 'ctrl', 1, 'GLT'),
#  (152, Decimal('0.3079'), Decimal('3.4338'), 1, 'ctrl', 1, 'GLT'),
#  (153, Decimal('0.3652'), Decimal('3.857'), 1, 'ctrl', 1, 'GLT'),
#  (154, Decimal('0.1826'), Decimal('2.6287'), 1, 'ctrl', 1, 'GLT'),
#  (155, Decimal('0.358'), Decimal('4.0234'), 1, 'ctrl', 1, 'GLT'),
#  (156, Decimal('0.3616'), Decimal('3.6778'), 1, 'ctrl', 1, 'GLT'),
#  (157, Decimal('0.1361'), Decimal('1.9967'), 1, 'ctrl', 1, 'GLT'),
#  (158, Decimal('0.4296'), Decimal('4.3871'), 1, 'ctrl', 1, 'GLT'),
#  (159, Decimal('0.2685'), Decimal('3.0697'), 1, 'ctrl', 1, 'GLT'),
#  (160, Decimal('0.3652'), Decimal('3.7078'), 1, 'ctrl', 1, 'GLT'),
#  (161, Decimal('0.4189'), Decimal('4.2143'), 1, 'ctrl', 1, 'GLT'),
#  (162, Decimal('0.0823'), Decimal('1.3412'), 1, 'ctrl', 1, 'GLT'),
#  (163, Decimal('0.1683'), Decimal('2.0865'), 1, 'ctrl', 1, 'GLT'),
#  (164, Decimal('0.1683'), Decimal('2.5272'), 1, 'ctrl', 1, 'GLT'),
#  (165, Decimal('0.3366'), Decimal('3.6183'), 1, 'ctrl', 1, 'GLT'),
#  (166, Decimal('0.2041'), Decimal('2.8731'), 1, 'ctrl', 1, 'GLT'),
#  (167, Decimal('0.2041'), Decimal('3.4331'), 1, 'ctrl', 1, 'GLT'),
#  (168, Decimal('0.3079'), Decimal('3.3975'), 1, 'ctrl', 1, 'GLT'),
#  (169, Decimal('0.5585'), Decimal('5.7458'), 1, 'ctrl', 1, 'GLT'),
#  (170, Decimal('0.1361'), Decimal('2.0267'), 1, 'ctrl', 1, 'GLT'),
#  (171, Decimal('0.2936'), Decimal('3.4035'), 1, 'ctrl', 1, 'GLT'),
#  (172, Decimal('0.4726'), Decimal('4.8883'), 1, 'ctrl', 1, 'GLT'),
#  (173, Decimal('0.1933'), Decimal('2.6764'), 1, 'ctrl', 1, 'GLT'),
#  (174, Decimal('0.3545'), Decimal('3.8745'), 1, 'ctrl', 1, 'GLT'),
#  (175, Decimal('0.2757'), Decimal('3.0879'), 1, 'ctrl', 1, 'GLT'),
#  (176, Decimal('0.2542'), Decimal('3.1951'), 1, 'ctrl', 1, 'GLT'),
#  (177, Decimal('0.4189'), Decimal('4.4231'), 1, 'ctrl', 1, 'GLT'),
#  (178, Decimal('0.2077'), Decimal('2.6586'), 1, 'ctrl', 1, 'GLT'),
#  (179, Decimal('0.1611'), Decimal('2.0573'), 1, 'ctrl', 1, 'GLT'),
#  (180, Decimal('0.2972'), Decimal('3.2906'), 1, 'ctrl', 1, 'GLT'),
#  (181, Decimal('0.1933'), Decimal('2.8431'), 1, 'ctrl', 1, 'GLT'),
#  (182, Decimal('0.4619'), Decimal('4.8281'), 1, 'ctrl', 1, 'GLT'),
#  (183, Decimal('0.1611'), Decimal('2.2593'), 1, 'ctrl', 1, 'GLT'),
#  (184, Decimal('0.4619'), Decimal('4.6792'), 1, 'ctrl', 1, 'GLT'),
#  (185, Decimal('0.2112'), Decimal('2.903'), 1, 'ctrl', 1, 'GLT'),
#  (186, Decimal('0.2256'), Decimal('2.8852'), 1, 'ctrl', 1, 'GLT'),
#  (187, Decimal('0.2148'), Decimal('3.0102'), 1, 'ctrl', 1, 'GLT'),
#  (188, Decimal('0.5657'), Decimal('5.609'), 1, 'ctrl', 1, 'GLT'),
#  (189, Decimal('0.222'), Decimal('3.0341'), 1, 'ctrl', 1, 'GLT'),
#  (190, Decimal('0.3616'), Decimal('4.2083'), 1, 'ctrl', 1, 'GLT'),
#  (191, Decimal('0.3401'), Decimal('4.0654'), 1, 'ctrl', 1, 'GLT'),
#  (192, Decimal('0.1432'), Decimal('2.2233'), 1, 'ctrl', 1, 'GLT'),
#  (193, Decimal('0.2864'), Decimal('3.6358'), 1, 'ctrl', 1, 'GLT'),
#  (194, Decimal('0.1146'), Decimal('1.8478'), 1, 'ctrl', 1, 'GLT'),
#  (195, Decimal('0.2864'), Decimal('3.3743'), 1, 'ctrl', 1, 'GLT'),
#  (196, Decimal('0.2685'), Decimal('3.6536'), 1, 'ctrl', 1, 'GLT'),
#  (197, Decimal('0.2649'), Decimal('3.6002'), 1, 'ctrl', 1, 'GLT'),
#  (198, Decimal('0.1826'), Decimal('2.4321'), 1, 'ctrl', 1, 'GLT'),
#  (199, Decimal('0.1898'), Decimal('2.468'), 1, 'ctrl', 1, 'GLT'),
#  (200, Decimal('0.1647'), Decimal('2.4021'), 1, 'ctrl', 1, 'GLT'),
#  (201, Decimal('0.4082'), Decimal('4.8577'), 1, 'ctrl', 1, 'GLT'),
#  (202, Decimal('0.2578'), Decimal('2.9451'), 1, 'ctrl', 1, 'GLT'),
#  (203, Decimal('0.5013'), Decimal('4.3996'), 1, 'ctrl', 1, 'GLT'),
#  (204, Decimal('0.1898'), Decimal('3.0337'), 1, 'ctrl', 1, 'GLT'),
#  (205, Decimal('0.1038'), Decimal('1.6095'), 1, 'ctrl', 1, 'GLT'),
#  (206, Decimal('0.2399'), Decimal('2.9686'), 1, 'ctrl', 1, 'GLT'),
#  (207, Decimal('0.4475'), Decimal('5.0369'), 1, 'ctrl', 1, 'GLT'),
#  (208, Decimal('0.5156'), Decimal('5.2748'), 1, 'ctrl', 1, 'GLT'),
#  (209, Decimal('0.1468'), Decimal('2.3188'), 1, 'ctrl', 1, 'GLT'),
#  (210, Decimal('0.3151'), Decimal('3.5111'), 1, 'ctrl', 1, 'GLT'),
#  (211, Decimal('0.2148'), Decimal('2.8788'), 1, 'ctrl', 1, 'GLT'),
#  (212, Decimal('0.3938'), Decimal('4.0177'), 1, 'ctrl', 1, 'GLT'),
#  (213, Decimal('0.1396'), Decimal('2.2055'), 1, 'ctrl', 1, 'GLT'),
#  (214, Decimal('0.5013'), Decimal('5.3048'), 1, 'ctrl', 1, 'GLT'),
#  (215, Decimal('0.3974'), Decimal('3.9229'), 1, 'ctrl', 1, 'GLT'),
#  (216, Decimal('0.2649'), Decimal('2.7007'), 1, 'ctrl', 1, 'GLT'),
#  (217, Decimal('0.6409'), Decimal('5.9421'), 1, 'ctrl', 1, 'GLT'),
#  (218, Decimal('0.2721'), Decimal('3.1239'), 1, 'ctrl', 1, 'GLT'),
#  (219, Decimal('0.2614'), Decimal('2.9686'), 1, 'ctrl', 1, 'GLT'),
#  (220, Decimal('0.1289'), Decimal('1.8895'), 1, 'ctrl', 1, 'GLT'),
#  (221, Decimal('0.3008'), Decimal('2.9928'), 1, 'ctrl', 1, 'GLT'),
#  (222, Decimal('0.5013'), Decimal('4.8759'), 1, 'ctrl', 1, 'GLT'),
#  (223, Decimal('0.3151'), Decimal('3.6062'), 1, 'ctrl', 1, 'GLT'),
#  (224, Decimal('0.7805'), Decimal('6.8673'), 1, 'ctrl', 1, 'GLT'),
#  (225, Decimal('0.4368'), Decimal('4.7686'), 1, 'ctrl', 1, 'GLT'),
#  (226, Decimal('0.4225'), Decimal('4.6732'), 1, 'ctrl', 1, 'GLT'),
#  (227, Decimal('0.3545'), Decimal('3.7968'), 1, 'ctrl', 1, 'GLT'),
#  (228, Decimal('0.222'), Decimal('3.1114'), 1, 'ctrl', 1, 'GLT'),
#  (229, Decimal('0.2542'), Decimal('3.4391'), 1, 'ctrl', 1, 'GLT'),
#  (230, Decimal('0.3079'), Decimal('3.9578'), 1, 'ctrl', 1, 'GLT'),
#  (231, Decimal('0.2793'), Decimal('3.1727'), 1, 'ctrl', 1, 'GLT'),
#  (232, Decimal('0.469'), Decimal('4.9236'), 1, 'ctrl', 1, 'GLT'),
#  (233, Decimal('0.2041'), Decimal('2.7837'), 1, 'ctrl', 1, 'GLT'),
#  (234, Decimal('0.3473'), Decimal('3.4691'), 1, 'ctrl', 1, 'GLT'),
#  (235, Decimal('0.2649'), Decimal('3.499'), 1, 'ctrl', 1, 'GLT'),
#  (236, Decimal('0.3187'), Decimal('3.5763'), 1, 'ctrl', 1, 'GLT'),
#  (237, Decimal('0.4082'), Decimal('3.9999'), 1, 'ctrl', 1, 'GLT'),
#  (238, Decimal('0.1647'), Decimal('2.5866'), 1, 'ctrl', 1, 'GLT'),
#  (239, Decimal('0.2936'), Decimal('3.1239'), 1, 'ctrl', 1, 'GLT'),
#  (240, Decimal('0.0716'), Decimal('1.2935'), 1, 'ctrl', 1, 'GLT'),
#  (241, Decimal('0.4261'), Decimal('4.381'), 1, 'ctrl', 1, 'GLT'),
#  (242, Decimal('0.1325'), Decimal('2.0088'), 1, 'ctrl', 1, 'GLT'),
#  (243, Decimal('0.1862'), Decimal('2.6105'), 1, 'ctrl', 1, 'GLT'),
#  (244, Decimal('0.5406'), Decimal('4.5898'), 1, 'ctrl', 1, 'GLT'),
#  (245, Decimal('0.1468'), Decimal('2.0267'), 1, 'ctrl', 1, 'GLT'),
#  (246, Decimal('0.3079'), Decimal('3.624'), 1, 'ctrl', 1, 'GLT'),
#  (247, Decimal('0.222'), Decimal('2.9026'), 1, 'ctrl', 1, 'GLT'),
#  (248, Decimal('0.247'), Decimal('3.2251'), 1, 'ctrl', 1, 'GLT'),
#  (249, Decimal('0.3008'), Decimal('3.5706'), 1, 'ctrl', 1, 'GLT'),
#  (250, Decimal('0.2757'), Decimal('3.1292'), 1, 'ctrl', 1, 'GLT'),
#  (251, Decimal('0.2578'), Decimal('3.0879'), 1, 'ctrl', 1, 'GLT'),
#  (252, Decimal('0.913'), Decimal('7.5826'), 1, 'ctrl', 1, 'GLT'),
#  (253, Decimal('0.1468'), Decimal('2.0922'), 1, 'ctrl', 1, 'GLT'),
#  (254, Decimal('0.5156'), Decimal('4.8164'), 1, 'ctrl', 1, 'GLT'),
#  (255, Decimal('0.1933'), Decimal('2.6465'), 1, 'ctrl', 1, 'GLT'),
#  (256, Decimal('0.1504'), Decimal('2.3006'), 1, 'ctrl', 1, 'GLT'),
#  (257, Decimal('0.5764'), Decimal('5.4961'), 1, 'ctrl', 1, 'GLT'),
#  (258, Decimal('0.6087'), Decimal('6.6937'), 1, 'ctrl', 1, 'GLT'),
#  (259, Decimal('0.5371'), Decimal('5.7401'), 1, 'ctrl', 1, 'GLT'),
#  (260, Decimal('0.3222'), Decimal('3.8445'), 1, 'ctrl', 1, 'GLT'),
#  (261, Decimal('0.3795'), Decimal('4.0298'), 1, 'ctrl', 1, 'GLT'),
#  (262, Decimal('0.5979'), Decimal('5.6567'), 1, 'ctrl', 1, 'GLT'),
#  (263, Decimal('0.0859'), Decimal('1.6095'), 1, 'ctrl', 1, 'GLT'),
#  (264, Decimal('0.0967'), Decimal('1.5917'), 1, 'ctrl', 1, 'GLT'),
#  (265, Decimal('0.2721'), Decimal('3.1595'), 1, 'ctrl', 1, 'GLT'),
#  (266, Decimal('0.3759'), Decimal('4.2799'), 1, 'ctrl', 1, 'GLT'),
#  (267, Decimal('0.2041'), Decimal('2.5931'), 1, 'ctrl', 1, 'GLT'),
#  (268, Decimal('0.3795'), Decimal('4.2321'), 1, 'ctrl', 1, 'GLT'),
#  (269, Decimal('0.247'), Decimal('3.0637'), 1, 'ctrl', 1, 'GLT'),
#  (270, Decimal('0.5585'), Decimal('5.3942'), 1, 'ctrl', 1, 'GLT'),
#  (271, Decimal('0.2041'), Decimal('2.5404'), 1, 'ctrl', 1, 'GLT'),
#  (272, Decimal('0.4619'), Decimal('4.6201'), 1, 'ctrl', 1, 'GLT'),
#  (273, Decimal('0.2649'), Decimal('3.2008'), 1, 'ctrl', 1, 'GLT'),
#  (274, Decimal('0.3043'), Decimal('3.3679'), 1, 'ctrl', 1, 'GLT'),
#  (275, Decimal('0.469'), Decimal('4.5481'), 1, 'ctrl', 1, 'GLT'),
#  (276, Decimal('0.1182'), Decimal('1.8418'), 1, 'ctrl', 1, 'GLT'),
#  (277, Decimal('0.1396'), Decimal('1.9433'), 1, 'ctrl', 1, 'GLT'),
#  (278, Decimal('0.358'), Decimal('4.4826'), 1, 'ctrl', 1, 'GLT'),
#  (279, Decimal('0.3652'), Decimal('4.1427'), 1, 'ctrl', 1, 'GLT'),
#  (280, Decimal('0.4189'), Decimal('4.4466'), 1, 'ctrl', 1, 'GLT'),
#  (281, Decimal('0.6122'), Decimal('5.448'), 1, 'ctrl', 1, 'GLT'),
#  (282, Decimal('0.3115'), Decimal('3.1709'), 1, 'ctrl', 1, 'GLT'),
#  (283, Decimal('0.4296'), Decimal('4.0298'), 1, 'ctrl', 1, 'GLT'),
#  (284, Decimal('0.2112'), Decimal('2.2892'), 1, 'ctrl', 1, 'GLT'),
#  (285, Decimal('0.7841'), Decimal('6.0985'), 1, 'ctrl', 1, 'GLT'),
#  (286, Decimal('0.1504'), Decimal('2.0028'), 1, 'ctrl', 1, 'GLT'),
#  (287, Decimal('0.0859'), Decimal('1.4784'), 1, 'ctrl', 1, 'GLT'),
#  (288, Decimal('0.6624'), Decimal('6.086'), 1, 'ctrl', 1, 'GLT'),
#  (289, Decimal('0.5335'), Decimal('5.0251'), 1, 'ctrl', 1, 'GLT'),
#  (290, Decimal('0.3043'), Decimal('3.654'), 1, 'ctrl', 1, 'GLT'),
#  (291, Decimal('0.8056'), Decimal('6.8972'), 1, 'ctrl', 1, 'GLT'),
#  (292, Decimal('0.5908'), Decimal('5.5491'), 1, 'ctrl', 1, 'GLT'),
#  (293, Decimal('0.5048'), Decimal('5.0786'), 1, 'ctrl', 1, 'GLT'),
#  (294, Decimal('0.1325'), Decimal('2.2233'), 1, 'ctrl', 1, 'GLT'),
#  (295, Decimal('0.6982'), Decimal('6.5327'), 1, 'ctrl', 1, 'GLT'),
#  (296, Decimal('0.3294'), Decimal('3.4217'), 1, 'ctrl', 1, 'GLT'),
#  (297, Decimal('0.3401'), Decimal('3.3262'), 1, 'ctrl', 1, 'GLT'),
#  (298, Decimal('0.2005'), Decimal('2.5272'), 1, 'ctrl', 1, 'GLT'),
#  (299, Decimal('0.2005'), Decimal('2.992'), 1, 'ctrl', 1, 'GLT'),
#  (300, Decimal('0.1862'), Decimal('2.2532'), 1, 'ctrl', 1, 'GLT'),
#  (301, Decimal('0.3008'), Decimal('3.1413'), 1, 'ctrl', 1, 'GLT'),
#  (302, Decimal('0.3008'), Decimal('3.6956'), 1, 'ctrl', 1, 'GLT'),
#  (303, Decimal('0.3008'), Decimal('3.6301'), 1, 'ctrl', 1, 'GLT'),
#  (304, Decimal('0.3151'), Decimal('3.4456'), 1, 'ctrl', 1, 'GLT'),
#  (305, Decimal('0.2828'), Decimal('3.4334'), 1, 'ctrl', 1, 'GLT'),
#  (306, Decimal('0.8235'), Decimal('7.4511'), 1, 'ctrl', 1, 'GLT'),
#  (307, Decimal('0.2936'), Decimal('3.7134'), 1, 'ctrl', 1, 'GLT'),
#  (308, Decimal('0.0967'), Decimal('1.675'), 1, 'ctrl', 1, 'GLT'),
#  (309, Decimal('0.3616'), Decimal('4.0116'), 1, 'ctrl', 1, 'GLT'),
#  (310, Decimal('0.4189'), Decimal('4.3337'), 1, 'ctrl', 1, 'GLT'),
#  (311, Decimal('0.2721'), Decimal('3.1235'), 1, 'ctrl', 1, 'GLT'),
#  (312, Decimal('0.1969'), Decimal('2.4737'), 1, 'ctrl', 1, 'GLT'),
#  (313, Decimal('0.333'), Decimal('3.7134'), 1, 'ctrl', 1, 'GLT'),
#  (314, Decimal('0.3938'), Decimal('4.256'), 1, 'ctrl', 1, 'GLT'),
#  (315, Decimal('0.0537'), Decimal('1.3231'), 1, 'ctrl', 1, 'GLT'),
#  (316, Decimal('0.4654'), Decimal('4.0953'), 1, 'ctrl', 1, 'GLT'),
#  (317, Decimal('0.2256'), Decimal('2.7242'), 1, 'ctrl', 1, 'GLT'),
#  (318, Decimal('0.5299'), Decimal('6.5502'), 1, 'ctrl', 1, 'GLT'),
#  (319, Decimal('0.3831'), Decimal('4.1014'), 1, 'ctrl', 1, 'GLT'),
#  (320, Decimal('0.5084'), Decimal('5.0607'), 1, 'ctrl', 1, 'GLT'),
#  (321, Decimal('0.1361'), Decimal('1.985'), 1, 'ctrl', 1, 'GLT'),
#  (322, Decimal('0.2291'), Decimal('2.742'), 1, 'ctrl', 1, 'GLT'),
#  (323, Decimal('0.4619'), Decimal('4.6614'), 1, 'ctrl', 1, 'GLT'),
#  (324, Decimal('0.5585'), Decimal('5.6802'), 1, 'ctrl', 1, 'GLT'),
#  (325, Decimal('0.3258'), Decimal('3.6835'), 1, 'ctrl', 1, 'GLT'),
#  (326, Decimal('0.1396'), Decimal('1.7944'), 1, 'ctrl', 1, 'GLT'),
#  (327, Decimal('0.2757'), Decimal('2.8556'), 1, 'ctrl', 1, 'GLT'),
#  (328, Decimal('0.3008'), Decimal('4.1605'), 1, 'ctrl', 1, 'GLT'),
#  (329, Decimal('0.5621'), Decimal('5.9962'), 1, 'ctrl', 1, 'GLT'),
#  (330, Decimal('0.3652'), Decimal('3.7381'), 1, 'ctrl', 1, 'GLT'),
#  (331, Decimal('0.5908'), Decimal('5.1089'), 1, 'ctrl', 1, 'GLT'),
#  (332, Decimal('0.2399'), Decimal('2.7185'), 1, 'ctrl', 1, 'GLT'),
#  (333, Decimal('0.3258'), Decimal('3.577'), 1, 'ctrl', 1, 'GLT'),
#  (334, Decimal('0.5442'), Decimal('5.2873'), 1, 'ctrl', 1, 'GLT'),
#  (335, Decimal('0.3079'), Decimal('3.779'), 1, 'ctrl', 1, 'GLT'),
#  (336, Decimal('0.5836'), Decimal('5.9072'), 1, 'ctrl', 1, 'GLT'),
#  (337, Decimal('0.5048'), Decimal('4.7872'), 1, 'ctrl', 1, 'GLT'),
#  (338, Decimal('0.333'), Decimal('3.6005'), 1, 'ctrl', 1, 'GLT'),
#  (339, Decimal('0.0752'), Decimal('1.2696'), 1, 'ctrl', 1, 'GLT'),
#  (340, Decimal('0.4332'), Decimal('4.8103'), 1, 'ctrl', 1, 'GLT'),
#  (341, Decimal('0.3401'), Decimal('3.6183'), 1, 'ctrl', 1, 'GLT'),
#  (342, Decimal('0.2256'), Decimal('2.7719'), 1, 'ctrl', 1, 'GLT'),
#  (343, Decimal('0.2148'), Decimal('2.5275'), 1, 'ctrl', 1, 'GLT'),
#  (344, Decimal('0.3008'), Decimal('3.3023'), 1, 'ctrl', 1, 'GLT'),
#  (345, Decimal('0.2542'), Decimal('3.1534'), 1, 'ctrl', 1, 'GLT'),
#  (346, Decimal('0.0179'), Decimal('0.5304'), 1, 'ctrl', 1, 'GLT'),
#  (347, Decimal('0.2721'), Decimal('3.2129'), 1, 'ctrl', 1, 'GLT'),
#  (348, Decimal('0.2399'), Decimal('2.9386'), 1, 'ctrl', 1, 'GLT'),
#  (349, Decimal('0.2184'), Decimal('2.8909'), 1, 'ctrl', 1, 'GLT'),
#  (350, Decimal('0.4404'), Decimal('4.5955'), 1, 'ctrl', 1, 'GLT'),
#  (351, Decimal('0.2721'), Decimal('3.4812'), 1, 'ctrl', 1, 'GLT'),
#  (352, Decimal('0.3366'), Decimal('3.8627'), 1, 'ctrl', 1, 'GLT'),
#  (353, Decimal('0.3903'), Decimal('4.1844'), 1, 'ctrl', 1, 'GLT'),
#  (354, Decimal('0.4261'), Decimal('4.5421'), 1, 'ctrl', 1, 'GLT'),
#  (355, Decimal('0.2005'), Decimal('2.992'), 1, 'ctrl', 1, 'GLT'),
#  (356, Decimal('0.5048'), Decimal('4.7573'), 1, 'ctrl', 1, 'GLT'),
#  (357, Decimal('0.4082'), Decimal('4.417'), 1, 'ctrl', 1, 'GLT'),
#  (358, Decimal('0.8808'), Decimal('7.4985'), 1, 'ctrl', 1, 'GLT'),
#  (359, Decimal('0.2435'), Decimal('2.903'), 1, 'ctrl', 1, 'GLT'),
#  (360, Decimal('0.2721'), Decimal('3.1235'), 1, 'ctrl', 1, 'GLT'),
#  (361, Decimal('0.1862'), Decimal('2.3369'), 1, 'ctrl', 1, 'GLT'),
#  (362, Decimal('0.6373'), Decimal('5.8897'), 1, 'ctrl', 1, 'GLT'),
#  (363, Decimal('0.5836'), Decimal('5.651'), 1, 'ctrl', 1, 'GLT'),
#  (364, Decimal('0.3903'), Decimal('4.381'), 1, 'ctrl', 1, 'GLT'),
#  (365, Decimal('0.1182'), Decimal('1.5439'), 1, 'ctrl', 1, 'GLT'),
#  (366, Decimal('0.1898'), Decimal('2.5631'), 1, 'ctrl', 1, 'GLT'),
#  (367, Decimal('0.1754'), Decimal('2.6109'), 1, 'ctrl', 1, 'GLT'),
#  (368, Decimal('0.6266'), Decimal('6.7297'), 1, 'ctrl', 1, 'GLT'),
#  (369, Decimal('0.1647'), Decimal('2.3248'), 1, 'ctrl', 1, 'GLT'),
#  (370, Decimal('0.2148'), Decimal('2.867'), 1, 'ctrl', 1, 'GLT'),
#  (371, Decimal('0.3974'), Decimal('3.9639'), 1, 'ctrl', 1, 'GLT'),
#  (372, Decimal('0.0859'), Decimal('1.5796'), 1, 'ctrl', 1, 'GLT'),
#  (373, Decimal('0.3688'), Decimal('4.3272'), 1, 'ctrl', 1, 'GLT'),
#  (374, Decimal('0.1611'), Decimal('2.2115'), 1, 'ctrl', 1, 'GLT'),
#  (375, Decimal('0.4332'), Decimal('4.8099'), 1, 'ctrl', 1, 'GLT'),
#  (376, Decimal('0.4153'), Decimal('4.6372'), 1, 'ctrl', 1, 'GLT'),
#  (377, Decimal('0.4225'), Decimal('4.2382'), 1, 'ctrl', 1, 'GLT'),
#  (378, Decimal('0.5872'), Decimal('5.6207'), 1, 'ctrl', 1, 'GLT'),
#  (379, Decimal('0.3115'), Decimal('3.6244'), 1, 'ctrl', 1, 'GLT'),
#  (380, Decimal('0.0107'), Decimal('0.3338'), 1, 'ctrl', 1, 'GLT'),
#  (381, Decimal('2.1232'), Decimal('15.0254'), 1, 'ctrl', 1, 'GLT'),
#  (382, Decimal('0.6122'), Decimal('5.2752'), 1, 'ctrl', 1, 'GLT'),
#  (383, Decimal('0.1683'), Decimal('2.6048'), 1, 'ctrl', 1, 'GLT'),
#  (384, Decimal('0.0895'), Decimal('1.3829'), 1, 'ctrl', 1, 'GLT'),
#  (385, Decimal('0.3043'), Decimal('3.452'), 1, 'ctrl', 1, 'GLT'),
#  (386, Decimal('0.3473'), Decimal('3.976'), 1, 'ctrl', 1, 'GLT'),
#  (387, Decimal('0.2112'), Decimal('2.903'), 1, 'ctrl', 1, 'GLT'),
#  (388, Decimal('0.3509'), Decimal('3.3145'), 1, 'ctrl', 1, 'GLT'),
#  (389, Decimal('0.2793'), Decimal('2.7723'), 1, 'ctrl', 1, 'GLT'),
#  (390, Decimal('0.5192'), Decimal('5.3411'), 1, 'ctrl', 1, 'GLT'),
#  (391, Decimal('0.1862'), Decimal('2.6287'), 1, 'ctrl', 1, 'GLT'),
#  (392, Decimal('0.1468'), Decimal('1.9016'), 1, 'ctrl', 1, 'GLT'),
#  (393, Decimal('0.4475'), Decimal('5.3881'), 1, 'ctrl', 1, 'GLT'),
#  (394, Decimal('0.2578'), Decimal('3.183'), 1, 'ctrl', 1, 'GLT'),
#  (395, Decimal('0.1217'), Decimal('2.0922'), 1, 'ctrl', 1, 'GLT'),
#  (396, Decimal('0.222'), Decimal('2.748'), 1, 'ctrl', 1, 'GLT'),
#  (397, Decimal('0.4726'), Decimal('4.4113'), 1, 'ctrl', 1, 'GLT'),
#  (398, Decimal('0.4619'), Decimal('4.691'), 1, 'ctrl', 1, 'GLT'),
#  (399, Decimal('0.1182'), Decimal('2.0445'), 1, 'ctrl', 1, 'GLT'),
#  (400, Decimal('0.1182'), Decimal('2.0505'), 1, 'ctrl', 1, 'GLT'),
#  (401, Decimal('0.2614'), Decimal('3.0163'), 1, 'ctrl', 1, 'GLT'),
#  (402, Decimal('0.3616'), Decimal('4.0294'), 1, 'ctrl', 1, 'GLT'),
#  (403, Decimal('0.3151'), Decimal('3.3501'), 1, 'ctrl', 1, 'GLT'),
#  (404, Decimal('0.3437'), Decimal('3.7794'), 1, 'ctrl', 1, 'GLT'),
#  (405, Decimal('0.2399'), Decimal('2.587'), 1, 'ctrl', 1, 'GLT'),
#  (406, Decimal('0.1683'), Decimal('2.2475'), 1, 'ctrl', 1, 'GLT'),
#  (407, Decimal('0.3222'), Decimal('3.3262'), 1, 'ctrl', 1, 'GLT'),
#  (408, Decimal('0.0823'), Decimal('1.4663'), 1, 'ctrl', 1, 'GLT'),
#  (409, Decimal('0.0573'), Decimal('1.3469'), 1, 'ctrl', 1, 'GLT'),
#  (410, Decimal('0.3258'), Decimal('3.9101'), 1, 'ctrl', 1, 'GLT'),
#  (411, Decimal('0.759'), Decimal('6.3721'), 1, 'ctrl', 1, 'GLT'),
#  (412, Decimal('0.358'), Decimal('4.1188'), 1, 'ctrl', 1, 'GLT'),
#  (413, Decimal('0.4583'), Decimal('5.3169'), 1, 'ctrl', 1, 'GLT'),
#  (414, Decimal('0.1611'), Decimal('2.1816'), 1, 'ctrl', 1, 'GLT'),
#  (415, Decimal('0.2291'), Decimal('2.6287'), 1, 'ctrl', 1, 'GLT'),
#  (416, Decimal('0.3759'), Decimal('4.5542'), 1, 'ctrl', 1, 'GLT'),
#  (417, Decimal('0.2077'), Decimal('3.0102'), 1, 'ctrl', 1, 'GLT'),
#  (418, Decimal('0.2184'), Decimal('2.7003'), 1, 'ctrl', 1, 'GLT'),
#  (419, Decimal('0.4189'), Decimal('3.9286'), 1, 'ctrl', 1, 'GLT'),
#  (420, Decimal('0.4798'), Decimal('5.2627'), 1, 'ctrl', 1, 'GLT'),
#  (421, Decimal('0.3688'), Decimal('4.1067'), 1, 'ctrl', 1, 'GLT'),
#  (422, Decimal('0.247'), Decimal('3.0701'), 1, 'ctrl', 1, 'GLT'),
#  (423, Decimal('0.2864'), Decimal('3.4035'), 1, 'ctrl', 1, 'GLT'),
#  (424, Decimal('0.3222'), Decimal('3.6896'), 1, 'ctrl', 1, 'GLT'),
#  (425, Decimal('0.6194'), Decimal('6.8423'), 1, 'ctrl', 1, 'GLT'),
#  (426, Decimal('0.3187'), Decimal('3.7252'), 1, 'ctrl', 1, 'GLT'),
#  (427, Decimal('0.5764'), Decimal('5.0073'), 1, 'ctrl', 1, 'GLT'),
#  (428, Decimal('0.1647'), Decimal('2.4199'), 1, 'ctrl', 1, 'GLT'),
#  (429, Decimal('0.358'), Decimal('4.2802'), 1, 'ctrl', 1, 'GLT'),
#  (430, Decimal('0.3008'), Decimal('3.4929'), 1, 'ctrl', 1, 'GLT'),
#  (431, Decimal('0.5585'), Decimal('5.8117'), 1, 'ctrl', 1, 'GLT'),
#  (432, Decimal('0.5693'), Decimal('5.9724'), 1, 'ctrl', 1, 'GLT'),
#  (433, Decimal('0.3473'), Decimal('3.6301'), 1, 'ctrl', 1, 'GLT'),
#  (434, Decimal('0.1361'), Decimal('1.7645'), 1, 'ctrl', 1, 'GLT'),
#  (435, Decimal('0.2578'), Decimal('3.2251'), 1, 'ctrl', 1, 'GLT'),
#  (436, Decimal('0.0609'), Decimal('1.0014'), 1, 'ctrl', 1, 'GLT'),
#  (437, Decimal('0.4762'), Decimal('4.8103'), 1, 'ctrl', 1, 'GLT'),
#  (438, Decimal('0.3938'), Decimal('4.381'), 1, 'ctrl', 1, 'GLT'),
#  (439, Decimal('0.2005'), Decimal('2.3191'), 1, 'ctrl', 1, 'GLT'),
#  (440, Decimal('0.154'), Decimal('2.1937'), 1, 'ctrl', 1, 'GLT'),
#  (441, Decimal('0.1325'), Decimal('2.1161'), 1, 'ctrl', 1, 'GLT'),
#  (442, Decimal('0.4117'), Decimal('4.7508'), 1, 'ctrl', 1, 'GLT'),
#  (443, Decimal('0.1217'), Decimal('1.9907'), 1, 'ctrl', 1, 'GLT'),
#  (444, Decimal('0.3187'), Decimal('3.1891'), 1, 'ctrl', 1, 'GLT'),
#  (445, Decimal('0.4511'), Decimal('4.4587'), 1, 'ctrl', 1, 'GLT'),
#  (446, Decimal('0.3222'), Decimal('3.7195'), 1, 'ctrl', 1, 'GLT'),
#  (447, Decimal('0.1504'), Decimal('2.0983'), 1, 'ctrl', 1, 'GLT'),
#  (448, Decimal('0.58'), Decimal('5.3176'), 1, 'ctrl', 1, 'GLT'),
#  (449, Decimal('0.2542'), Decimal('2.9507'), 1, 'ctrl', 1, 'GLT'),
#  (450, Decimal('0.9023'), Decimal('7.1654'), 1, 'ctrl', 1, 'GLT'),
#  (451, Decimal('0.3437'), Decimal('3.4812'), 1, 'ctrl', 1, 'GLT'),
#  (452, Decimal('0.87'), Decimal('7.2837'), 1, 'ctrl', 1, 'GLT'),
#  (453, Decimal('0.7698'), Decimal('6.6346'), 1, 'ctrl', 1, 'GLT'),
#  (454, Decimal('0.3366'), Decimal('3.8089'), 1, 'ctrl', 1, 'GLT'),
#  (455, Decimal('0.1504'), Decimal('2.1342'), 1, 'ctrl', 1, 'GLT'),
#  (456, Decimal('0.2435'), Decimal('3.0936'), 1, 'ctrl', 1, 'GLT'),
#  (457, Decimal('0.5943'), Decimal('5.4662'), 1, 'ctrl', 1, 'GLT'),
#  (458, Decimal('0.1719'), Decimal('3.0932'), 1, 'ctrl', 1, 'GLT'),
#  (459, Decimal('0.6373'), Decimal('6.0383'), 1, 'ctrl', 1, 'GLT'),
#  (460, Decimal('0.3688'), Decimal('4.3867'), 1, 'ctrl', 1, 'GLT'),
#  (461, Decimal('0.4296'), Decimal('4.6315'), 1, 'ctrl', 1, 'GLT'),
#  (462, Decimal('0.5979'), Decimal('5.4897'), 1, 'ctrl', 1, 'GLT'),
#  (463, Decimal('0.3509'), Decimal('3.9105'), 1, 'ctrl', 1, 'GLT'),
#  (464, Decimal('0.5335'), Decimal('4.6553'), 1, 'ctrl', 1, 'GLT'),
#  (465, Decimal('0.1575'), Decimal('2.3722'), 1, 'ctrl', 1, 'GLT'),
#  (466, Decimal('0.5478'), Decimal('4.8342'), 1, 'ctrl', 1, 'GLT'),
#  (467, Decimal('0.4082'), Decimal('3.5892'), 1, 'ctrl', 1, 'GLT'),
#  (468, Decimal('0.7161'), Decimal('6.5744'), 1, 'ctrl', 1, 'GLT'),
#  (469, Decimal('0.2721'), Decimal('3.4872'), 1, 'ctrl', 1, 'GLT'),
#  (470, Decimal('0.1826'), Decimal('2.2771'), 1, 'ctrl', 1, 'GLT'),
#  (471, Decimal('0.3509'), Decimal('4.1484'), 1, 'ctrl', 1, 'GLT'),
#  (472, Decimal('0.4547'), Decimal('5.3646'), 1, 'ctrl', 1, 'GLT'),
#  (473, Decimal('0.3831'), Decimal('4.1488'), 1, 'ctrl', 1, 'GLT'),
#  (474, Decimal('0.5335'), Decimal('5.0486'), 1, 'ctrl', 1, 'GLT'),
#  (475, Decimal('0.2578'), Decimal('3.3675'), 1, 'ctrl', 1, 'GLT'),
#  (476, Decimal('0.2399'), Decimal('3.0102'), 1, 'ctrl', 1, 'GLT'),
#  (477, Decimal('0.7304'), Decimal('6.6767'), 1, 'ctrl', 1, 'GLT'),
#  (478, Decimal('0.2972'), Decimal('3.2607'), 1, 'ctrl', 1, 'GLT'),
#  (479, Decimal('0.8306'), Decimal('6.8669'), 1, 'ctrl', 1, 'GLT'),
#  (480, Decimal('0.3509'), Decimal('4.4939'), 1, 'ctrl', 1, 'GLT'),
#  (481, Decimal('0.2828'), Decimal('3.499'), 1, 'ctrl', 1, 'GLT'),
#  (482, Decimal('0.1432'), Decimal('2.1577'), 1, 'ctrl', 1, 'GLT'),
#  (483, Decimal('0.043'), Decimal('0.912'), 1, 'ctrl', 1, 'GLT'),
#  (484, Decimal('0.3616'), Decimal('3.463'), 1, 'ctrl', 1, 'GLT'),
#  (485, Decimal('0.7662'), Decimal('7.2594'), 1, 'ctrl', 1, 'GLT'),
#  (486, Decimal('0.6624'), Decimal('6.6104'), 1, 'ctrl', 1, 'GLT'),
#  (487, Decimal('0.7161'), Decimal('6.5505'), 1, 'ctrl', 1, 'GLT'),
#  (488, Decimal('0.1468'), Decimal('1.8122'), 1, 'ctrl', 1, 'GLT'),
#  (489, Decimal('0.247'), Decimal('2.6052'), 1, 'ctrl', 1, 'GLT'),
#  (490, Decimal('0.1504'), Decimal('2.4025'), 1, 'ctrl', 1, 'GLT'),
#  (491, Decimal('0.2327'), Decimal('2.778'), 1, 'ctrl', 1, 'GLT'),
#  (492, Decimal('0.3473'), Decimal('3.7851'), 1, 'ctrl', 1, 'GLT'),
#  (493, Decimal('0.3222'), Decimal('4.1901'), 1, 'ctrl', 1, 'GLT'),
#  (494, Decimal('0.1969'), Decimal('2.784'), 1, 'ctrl', 1, 'GLT'),
#  (495, Decimal('0.0967'), Decimal('1.7345'), 1, 'ctrl', 1, 'GLT'),
#  (496, Decimal('0.1325'), Decimal('2.0088'), 1, 'ctrl', 1, 'GLT'),
#  (497, Decimal('0.2435'), Decimal('2.9985'), 1, 'ctrl', 1, 'GLT'),
#  (498, Decimal('0.4082'), Decimal('4.6194'), 1, 'ctrl', 1, 'GLT'),
#  (499, Decimal('0.1504'), Decimal('2.2112'), 1, 'ctrl', 1, 'GLT'),
#  (500, Decimal('0.1289'), Decimal('1.8956'), 1, 'ctrl', 1, 'GLT'),
#  (501, Decimal('0.3509'), Decimal('4.059'), 1, 'ctrl', 1, 'GLT'),
#  (502, Decimal('0.1504'), Decimal('2.3783'), 1, 'ctrl', 1, 'GLT'),
#  (503, Decimal('0.358'), Decimal('3.9995'), 1, 'ctrl', 1, 'GLT'),
#  (504, Decimal('0.5335'), Decimal('5.4779'), 1, 'ctrl', 1, 'GLT'),
#  (505, Decimal('0.2614'), Decimal('3.6418'), 1, 'ctrl', 1, 'GLT'),
#  (506, Decimal('0.333'), Decimal('4.0052'), 1, 'ctrl', 1, 'GLT'),
#  (507, Decimal('0.2614'), Decimal('3.1296'), 1, 'ctrl', 1, 'GLT'),
#  (508, Decimal('0.5084'), Decimal('4.6019'), 1, 'ctrl', 1, 'GLT'),
#  (509, Decimal('0.2972'), Decimal('3.6005'), 1, 'ctrl', 1, 'GLT'),
#  (510, Decimal('0.2542'), Decimal('3.0398'), 1, 'ctrl', 1, 'GLT'),
#  (511, Decimal('0.802'), Decimal('6.7059'), 1, 'ctrl', 1, 'GLT'),
#  (512, Decimal('0.4547'), Decimal('5.0604'), 1, 'ctrl', 1, 'GLT'),
#  (513, Decimal('0.469'), Decimal('4.7448'), 1, 'ctrl', 1, 'GLT'),
#  (514, Decimal('0.3903'), Decimal('4.3988'), 1, 'ctrl', 1, 'GLT'),
#  (515, Decimal('0.2685'), Decimal('3.3796'), 1, 'ctrl', 1, 'GLT'),
#  (516, Decimal('0.1969'), Decimal('3.0042'), 1, 'ctrl', 1, 'GLT'),
#  (517, Decimal('0.3867'), Decimal('4.3511'), 1, 'ctrl', 1, 'GLT'),
#  (518, Decimal('0.3509'), Decimal('3.3978'), 1, 'ctrl', 1, 'GLT'),
#  (519, Decimal('0.0859'), Decimal('2.3063'), 1, 'ctrl', 1, 'GLT'),
#  (520, Decimal('0.179'), Decimal('2.4855'), 1, 'ctrl', 1, 'GLT'),
#  (521, Decimal('0.3795'), Decimal('4.4939'), 1, 'ctrl', 1, 'GLT'),
#  (522, Decimal('0.2112'), Decimal('2.468'), 1, 'ctrl', 1, 'GLT'),
#  (523, Decimal('0.2327'), Decimal('2.9447'), 1, 'ctrl', 1, 'GLT'),
#  (524, Decimal('0.5013'), Decimal('4.5421'), 1, 'ctrl', 1, 'GLT'),
#  (525, Decimal('0.0716'), Decimal('1.788'), 1, 'ctrl', 1, 'GLT'),
#  (526, Decimal('0.3795'), Decimal('4.7683'), 1, 'ctrl', 1, 'GLT'),
#  (527, Decimal('0.5299'), Decimal('5.2036'), 1, 'ctrl', 1, 'GLT'),
#  (528, Decimal('0.0179'), Decimal('0.4471'), 1, 'ctrl', 1, 'GLT'),
#  (529, Decimal('0.5192'), Decimal('5.2392'), 1, 'ctrl', 1, 'GLT'),
#  (530, Decimal('0.4762'), Decimal('5.0369'), 1, 'ctrl', 1, 'GLT'),
#  (531, Decimal('0.3473'), Decimal('3.8983'), 1, 'ctrl', 1, 'GLT'),
#  (532, Decimal('0.5908'), Decimal('5.6211'), 1, 'ctrl', 1, 'GLT'),
#  (533, Decimal('0.222'), Decimal('2.6226'), 1, 'ctrl', 1, 'GLT'),
#  (534, Decimal('0.1038'), Decimal('1.8596'), 1, 'ctrl', 1, 'GLT'),
#  (535, Decimal('0.3759'), Decimal('3.976'), 1, 'ctrl', 1, 'GLT'),
#  (536, Decimal('0.1575'), Decimal('2.2233'), 1, 'ctrl', 1, 'GLT'),
#  (537, Decimal('0.6301'), Decimal('5.8117'), 1, 'ctrl', 1, 'GLT'),
#  (538, Decimal('0.29'), Decimal('3.6123'), 1, 'ctrl', 1, 'GLT'),
#  (539, Decimal('0.2077'), Decimal('2.9803'), 1, 'ctrl', 1, 'GLT'),
#  (540, Decimal('0.512'), Decimal('4.5538'), 1, 'ctrl', 1, 'GLT'),
#  (541, Decimal('0.4296'), Decimal('4.7451'), 1, 'ctrl', 1, 'GLT'),
#  (542, Decimal('0.2112'), Decimal('2.8969'), 1, 'ctrl', 1, 'GLT'),
#  (543, Decimal('0.5514'), Decimal('5.4362'), 1, 'ctrl', 1, 'GLT'),
#  (544, Decimal('0.1647'), Decimal('2.4082'), 1, 'ctrl', 1, 'GLT'),
#  (545, Decimal('0.1253'), Decimal('1.7531'), 1, 'ctrl', 1, 'GLT'),
#  (546, Decimal('0.7483'), Decimal('6.7233'), 1, 'ctrl', 1, 'GLT'),
#  (547, Decimal('0.5764'), Decimal('5.7522'), 1, 'ctrl', 1, 'GLT'),
#  (548, Decimal('0.2291'), Decimal('2.9625'), 1, 'ctrl', 1, 'GLT'),
#  (549, Decimal('0.3008'), Decimal('3.6661'), 1, 'ctrl', 1, 'GLT'),
#  (550, Decimal('0.3903'), Decimal('4.7921'), 1, 'ctrl', 1, 'GLT'),
#  (551, Decimal('0.0967'), Decimal('1.4068'), 1, 'ctrl', 1, 'GLT'),
#  (552, Decimal('0.4475'), Decimal('4.9831'), 1, 'ctrl', 1, 'GLT'),
#  (553, Decimal('0.1396'), Decimal('2.1937'), 1, 'ctrl', 1, 'GLT'),
#  (554, Decimal('0.2936'), Decimal('3.6002'), 1, 'ctrl', 1, 'GLT'),
#  (555, Decimal('0.4117'), Decimal('4.6493'), 1, 'ctrl', 1, 'GLT'),
#  (556, Decimal('0.5013'), Decimal('5.0725'), 1, 'ctrl', 1, 'GLT'),
#  (557, Decimal('0.2649'), Decimal('2.9864'), 1, 'ctrl', 1, 'GLT'),
#  (558, Decimal('0.3688'), Decimal('4.1965'), 1, 'ctrl', 1, 'GLT'),
#  (559, Decimal('0.2578'), Decimal('3.0519'), 1, 'ctrl', 1, 'GLT'),
#  (560, Decimal('0.3616'), Decimal('4.2678'), 1, 'ctrl', 1, 'GLT'),
#  (561, Decimal('0.2256'), Decimal('3.0159'), 1, 'ctrl', 1, 'GLT'),
#  (562, Decimal('0.4798'), Decimal('4.6788'), 1, 'ctrl', 1, 'GLT'),
#  (563, Decimal('0.1719'), Decimal('2.4021'), 1, 'ctrl', 1, 'GLT'),
#  (564, Decimal('0.0931'), Decimal('1.3416'), 1, 'ctrl', 1, 'GLT'),
#  (565, Decimal('0.0895'), Decimal('1.6807'), 1, 'ctrl', 1, 'GLT'),
#  (566, Decimal('0.222'), Decimal('2.7954'), 1, 'ctrl', 1, 'GLT'),
#  (567, Decimal('0.1504'), Decimal('1.7705'), 1, 'ctrl', 1, 'GLT'),
#  (568, Decimal('0.2685'), Decimal('3.7013'), 1, 'ctrl', 1, 'GLT'),
#  (569, Decimal('0.3759'), Decimal('3.8983'), 1, 'ctrl', 1, 'GLT'),
#  (570, Decimal('0.2327'), Decimal('2.6764'), 1, 'ctrl', 1, 'GLT'),
#  (571, Decimal('0.3473'), Decimal('3.66'), 1, 'ctrl', 1, 'GLT'),
#  (572, Decimal('0.1862'), Decimal('2.581'), 1, 'ctrl', 1, 'GLT'),
#  (573, Decimal('0.3831'), Decimal('4.0472'), 1, 'ctrl', 1, 'GLT'),
#  (574, Decimal('0.2936'), Decimal('3.5464'), 1, 'ctrl', 1, 'GLT'),
#  (575, Decimal('0.4905'), Decimal('4.5902'), 1, 'ctrl', 1, 'GLT'),
#  (576, Decimal('0.5693'), Decimal('5.4662'), 1, 'ctrl', 1, 'GLT'),
#  (577, Decimal('0.3008'), Decimal('3.5884'), 1, 'ctrl', 1, 'GLT'),
#  (578, Decimal('0.9058'), Decimal('8.077'), 1, 'ctrl', 1, 'GLT'),
#  (579, Decimal('0.222'), Decimal('2.6825'), 1, 'ctrl', 1, 'GLT'),
#  (580, Decimal('0.1003'), Decimal('1.4962'), 1, 'ctrl', 1, 'GLT'),
#  (581, Decimal('0.0788'), Decimal('1.2696'), 1, 'ctrl', 1, 'GLT'),
#  (582, Decimal('0.5872'), Decimal('5.6924'), 1, 'ctrl', 1, 'GLT'),
#  (583, Decimal('0.333'), Decimal('4.131'), 1, 'ctrl', 1, 'GLT'),
#  (584, Decimal('0.1862'), Decimal('3.3493'), 1, 'ctrl', 1, 'GLT'),
#  (585, Decimal('0.1826'), Decimal('2.1521'), 1, 'ctrl', 1, 'GLT'),
#  (586, Decimal('0.4046'), Decimal('3.9756'), 1, 'ctrl', 1, 'GLT'),
#  (587, Decimal('0.1217'), Decimal('1.8717'), 1, 'ctrl', 1, 'GLT'),
#  (588, Decimal('0.2721'), Decimal('3.3262'), 1, 'ctrl', 1, 'GLT'),
#  (589, Decimal('0.1468'), Decimal('2.2888'), 1, 'ctrl', 1, 'GLT'),
#  (590, Decimal('0.4905'), Decimal('5.0729'), 1, 'ctrl', 1, 'GLT'),
#  (591, Decimal('0.1933'), Decimal('2.426'), 1, 'ctrl', 1, 'GLT'),
#  (592, Decimal('0.3437'), Decimal('3.8332'), 1, 'ctrl', 1, 'GLT'),
#  (593, Decimal('0.2506'), Decimal('2.6526'), 1, 'ctrl', 1, 'GLT'),
#  (594, Decimal('0.3222'), Decimal('3.6778'), 1, 'ctrl', 1, 'GLT'),
#  (595, Decimal('0.2936'), Decimal('3.7134'), 1, 'ctrl', 1, 'GLT'),
#  (596, Decimal('0.4082'), Decimal('4.7686'), 1, 'ctrl', 1, 'GLT'),
#  (597, Decimal('0.7841'), Decimal('7.569'), 1, 'ctrl', 1, 'GLT'),
#  (598, Decimal('0.6087'), Decimal('5.8598'), 1, 'ctrl', 1, 'GLT'),
#  (599, Decimal('0.1754'), Decimal('2.3904'), 1, 'ctrl', 1, 'GLT'),
#  (600, Decimal('0.3938'), Decimal('4.292'), 1, 'ctrl', 1, 'GLT'),
#  (601, Decimal('0.2256'), Decimal('3.4691'), 1, 'ctrl', 1, 'GLT'),
#  (602, Decimal('0.5406'), Decimal('5.3229'), 1, 'ctrl', 1, 'GLT'),
#  (603, Decimal('0.5227'), Decimal('5.049'), 1, 'ctrl', 1, 'GLT'),
#  (604, Decimal('0.6588'), Decimal('6.2285'), 1, 'ctrl', 1, 'GLT'),
#  (605, Decimal('0.5836'), Decimal('5.3051'), 1, 'ctrl', 1, 'GLT'),
#  (606, Decimal('0.3724'), Decimal('4.7326'), 1, 'ctrl', 1, 'GLT'),
#  (607, Decimal('0.2972'), Decimal('3.7851'), 1, 'ctrl', 1, 'GLT'),
#  (608, Decimal('0.1325'), Decimal('1.8664'), 1, 'ctrl', 1, 'GLT'),
#  (609, Decimal('0.1719'), Decimal('2.1581'), 1, 'ctrl', 1, 'GLT'),
#  (610, Decimal('0.3473'), Decimal('3.8388'), 1, 'ctrl', 1, 'GLT'),
#  (611, Decimal('0.4296'), Decimal('4.6788'), 1, 'ctrl', 1, 'GLT'),
#  (612, Decimal('0.1683'), Decimal('2.5332'), 1, 'ctrl', 1, 'GLT'),
#  (613, Decimal('0.1683'), Decimal('2.5988'), 1, 'ctrl', 1, 'GLT'),
#  (614, Decimal('0.4619'), Decimal('4.4705'), 1, 'ctrl', 1, 'GLT'),
#  (615, Decimal('0.2542'), Decimal('2.8375'), 1, 'ctrl', 1, 'GLT'),
#  (616, Decimal('0.0823'), Decimal('1.4485'), 1, 'ctrl', 1, 'GLT'),
#  (617, Decimal('0.3688'), Decimal('3.7733'), 1, 'ctrl', 1, 'GLT'),
#  (618, Decimal('0.7089'), Decimal('6.5032'), 1, 'ctrl', 1, 'GLT'),
#  (619, Decimal('0.2828'), Decimal('3.3561'), 1, 'ctrl', 1, 'GLT'),
#  (620, Decimal('0.6301'), Decimal('5.4726'), 1, 'ctrl', 1, 'GLT'),
#  (621, Decimal('0.2828'), Decimal('3.291'), 1, 'ctrl', 1, 'GLT'),
#  (622, Decimal('0.3294'), Decimal('3.3561'), 1, 'ctrl', 1, 'GLT'),
#  (623, Decimal('0.2972'), Decimal('3.7968'), 1, 'ctrl', 1, 'GLT'),
#  (624, Decimal('0.401'), Decimal('4.3507'), 1, 'ctrl', 1, 'GLT'),
#  (625, Decimal('0.3151'), Decimal('4.4223'), 1, 'ctrl', 1, 'GLT'),
#  (626, Decimal('0.2614'), Decimal('2.7424'), 1, 'ctrl', 1, 'GLT'),
#  (627, Decimal('0.4404'), Decimal('4.6853'), 1, 'ctrl', 1, 'GLT'),
#  (628, Decimal('0.0967'), Decimal('1.7584'), 1, 'ctrl', 1, 'GLT'),
#  (629, Decimal('0.2864'), Decimal('3.6418'), 1, 'ctrl', 1, 'GLT'),
#  (630, Decimal('0.5478'), Decimal('5.4897'), 1, 'ctrl', 1, 'GLT'),
#  (631, Decimal('0.0967'), Decimal('2.0145'), 1, 'ctrl', 1, 'GLT'),
#  (632, Decimal('0.1038'), Decimal('1.5618'), 1, 'ctrl', 1, 'GLT'),
#  (633, Decimal('0.154'), Decimal('2.0327'), 1, 'ctrl', 1, 'GLT'),
#  (634, Decimal('0.2041'), Decimal('3.4687'), 1, 'ctrl', 1, 'GLT'),
#  (635, Decimal('0.2077'), Decimal('2.7299'), 1, 'ctrl', 1, 'GLT'),
#  (636, Decimal('0.3473'), Decimal('3.5827'), 1, 'ctrl', 1, 'GLT'),
#  (637, Decimal('0.4261'), Decimal('4.1014'), 1, 'ctrl', 1, 'GLT'),
#  (638, Decimal('0.1504'), Decimal('2.1342'), 1, 'ctrl', 1, 'GLT'),
#  (639, Decimal('0.3258'), Decimal('3.5706'), 1, 'ctrl', 1, 'GLT'),
#  (640, Decimal('0.247'), Decimal('3.9158'), 1, 'ctrl', 1, 'GLT'),
#  (641, Decimal('0.3115'), Decimal('3.3978'), 1, 'ctrl', 1, 'GLT'),
#  (642, Decimal('0.2112'), Decimal('2.6291'), 1, 'ctrl', 1, 'GLT'),
#  (643, Decimal('0.1468'), Decimal('2.1161'), 1, 'ctrl', 1, 'GLT'),
#  (644, Decimal('0.1396'), Decimal('2.0505'), 1, 'ctrl', 1, 'GLT'),
#  (645, Decimal('0.247'), Decimal('3.0458'), 1, 'ctrl', 1, 'GLT'),
#  (646, Decimal('0.1575'), Decimal('1.9315'), 1, 'ctrl', 1, 'GLT'),
#  (647, Decimal('0.5764'), Decimal('5.4067'), 1, 'ctrl', 1, 'GLT'),
#  (648, Decimal('0.247'), Decimal('3.028'), 1, 'ctrl', 1, 'GLT'),
#  (649, Decimal('0.1683'), Decimal('2.6821'), 1, 'ctrl', 1, 'GLT'),
#  (650, Decimal('0.3151'), Decimal('3.3027'), 1, 'ctrl', 1, 'GLT'),
#  (651, Decimal('0.87'), Decimal('7.6834'), 1, 'ctrl', 1, 'GLT'),
#  (652, Decimal('0.2721'), Decimal('3.4751'), 1, 'ctrl', 1, 'GLT'),
#  (653, Decimal('0.1432'), Decimal('2.2294'), 1, 'ctrl', 1, 'GLT'),
#  (654, Decimal('0.3187'), Decimal('3.6596'), 1, 'ctrl', 1, 'GLT'),
#  (655, Decimal('0.7161'), Decimal('6.3781'), 1, 'ctrl', 1, 'GLT'),
#  (656, Decimal('0.179'), Decimal('2.3426'), 1, 'ctrl', 1, 'GLT'),
#  (657, Decimal('0.3115'), Decimal('4.0116'), 1, 'ctrl', 1, 'GLT'),
#  (658, Decimal('0.2757'), Decimal('3.2963'), 1, 'ctrl', 1, 'GLT'),
#  (659, Decimal('0.3724'), Decimal('3.9521'), 1, 'ctrl', 1, 'GLT'),
#  (660, Decimal('0.1647'), Decimal('2.4616'), 1, 'ctrl', 1, 'GLT'),
#  (661, Decimal('0.333'), Decimal('3.5948'), 1, 'ctrl', 1, 'GLT'),
#  (662, Decimal('0.2399'), Decimal('2.9629'), 1, 'ctrl', 1, 'GLT'),
#  (663, Decimal('0.5335'), Decimal('4.9122'), 1, 'ctrl', 1, 'GLT'),
#  (664, Decimal('0.2506'), Decimal('3.0758'), 1, 'ctrl', 1, 'GLT'),
#  (665, Decimal('0.3187'), Decimal('3.9874'), 1, 'ctrl', 1, 'GLT'),
#  (666, Decimal('0.1038'), Decimal('1.669'), 1, 'ctrl', 1, 'GLT'),
#  (667, Decimal('0.9739'), Decimal('8.5719'), 1, 'ctrl', 1, 'GLT'),
#  (668, Decimal('0.2542'), Decimal('2.9807'), 1, 'ctrl', 1, 'GLT'),
#  (669, Decimal('0.5621'), Decimal('5.6207'), 1, 'ctrl', 1, 'GLT'),
#  (670, Decimal('0.2112'), Decimal('2.748'), 1, 'ctrl', 1, 'GLT'),
#  (671, Decimal('0.0251'), Decimal('0.6854'), 1, 'ctrl', 1, 'GLT'),
#  (672, Decimal('0.4117'), Decimal('4.1726'), 1, 'ctrl', 1, 'GLT'),
#  (673, Decimal('0.0609'), Decimal('1.2935'), 1, 'ctrl', 1, 'GLT'),
#  (674, Decimal('0.555'), Decimal('5.1858'), 1, 'ctrl', 1, 'GLT'),
#  (675, Decimal('0.111'), Decimal('1.6989'), 1, 'ctrl', 1, 'GLT'),
#  (676, Decimal('0.2649'), Decimal('3.2008'), 1, 'ctrl', 1, 'GLT'),
#  (677, Decimal('0.0895'), Decimal('1.5557'), 1, 'ctrl', 1, 'GLT'),
#  (678, Decimal('0.4368'), Decimal('4.6792'), 1, 'ctrl', 1, 'GLT'),
#  (679, Decimal('0.2291'), Decimal('2.6526'), 1, 'ctrl', 1, 'GLT'),
#  (680, Decimal('0.3008'), Decimal('3.255'), 1, 'ctrl', 1, 'GLT'),
#  (681, Decimal('0.5013'), Decimal('5.4184'), 1, 'ctrl', 1, 'GLT'),
#  (682, Decimal('0.2793'), Decimal('3.4929'), 1, 'ctrl', 1, 'GLT'),
#  (683, Decimal('0.7411'), Decimal('6.3482'), 1, 'ctrl', 1, 'GLT'),
#  (684, Decimal('0.2291'), Decimal('2.8613'), 1, 'ctrl', 1, 'GLT'),
#  (685, Decimal('0.4941'), Decimal('4.6913'), 1, 'ctrl', 1, 'GLT'),
#  (686, Decimal('0.6015'), Decimal('5.3415'), 1, 'ctrl', 1, 'GLT'),
#  (687, Decimal('0.2578'), Decimal('3.2902'), 1, 'ctrl', 1, 'GLT'),
#  (688, Decimal('0.2506'), Decimal('3.1413'), 1, 'ctrl', 1, 'GLT'),
#  (689, Decimal('0.4905'), Decimal('4.9475'), 1, 'ctrl', 1, 'GLT'),
#  (690, Decimal('0.1325'), Decimal('2.0384'), 1, 'ctrl', 1, 'GLT'),
#  (691, Decimal('0.4619'), Decimal('4.7394'), 1, 'ctrl', 1, 'GLT'),
#  (692, Decimal('0.2685'), Decimal('3.2429'), 1, 'ctrl', 1, 'GLT'),
#  (693, Decimal('0.179'), Decimal('2.3548'), 1, 'ctrl', 1, 'GLT'),
#  (694, Decimal('0.2864'), Decimal('3.4513'), 1, 'ctrl', 1, 'GLT'),
#  (695, Decimal('0.2757'), Decimal('3.7551'), 1, 'ctrl', 1, 'GLT'),
#  (696, Decimal('0.2256'), Decimal('2.8257'), 1, 'ctrl', 1, 'GLT'),
#  (697, Decimal('0.1754'), Decimal('2.301'), 1, 'ctrl', 1, 'GLT'),
#  (698, Decimal('0.7734'), Decimal('6.5335'), 1, 'ctrl', 1, 'GLT'),
#  (699, Decimal('0.2578'), Decimal('3.1606'), 1, 'ctrl', 1, 'GLT'),
#  (700, Decimal('0.8199'), Decimal('7.2784'), 1, 'ctrl', 1, 'GLT'),
#  (701, Decimal('0.2077'), Decimal('2.4976'), 1, 'ctrl', 1, 'GLT'),
#  (702, Decimal('0.3509'), Decimal('3.7672'), 1, 'ctrl', 1, 'GLT'),
#  (703, Decimal('0.6552'), Decimal('5.4904'), 1, 'ctrl', 1, 'GLT'),
#  (704, Decimal('0.4404'), Decimal('5.6207'), 1, 'ctrl', 1, 'GLT'),
#  (705, Decimal('0.068'), Decimal('1.1147'), 1, 'ctrl', 1, 'GLT'),
#  (706, Decimal('0.154'), Decimal('2.4794'), 1, 'ctrl', 1, 'GLT'),
#  (707, Decimal('0.3222'), Decimal('3.7851'), 1, 'ctrl', 1, 'GLT'),
#  (708, Decimal('0.3509'), Decimal('3.8324'), 1, 'ctrl', 1, 'GLT'),
#  (709, Decimal('0.2291'), Decimal('2.7302'), 1, 'ctrl', 1, 'GLT'),
#  (710, Decimal('0.5729'), Decimal('5.4897'), 1, 'ctrl', 1, 'GLT'),
#  (711, Decimal('0.5836'), Decimal('5.9428'), 1, 'ctrl', 1, 'GLT'),
#  (712, Decimal('0.2578'), Decimal('3.0762'), 1, 'ctrl', 1, 'GLT'),
#  (713, Decimal('0.3545'), Decimal('4.2083'), 1, 'ctrl', 1, 'GLT'),
#  (714, Decimal('0.1289'), Decimal('1.9967'), 1, 'ctrl', 1, 'GLT'),
#  (715, Decimal('0.444'), Decimal('4.4405'), 1, 'ctrl', 1, 'GLT'),
#  (716, Decimal('0.5621'), Decimal('5.3586'), 1, 'ctrl', 1, 'GLT'),
#  (717, Decimal('0.3473'), Decimal('3.4156'), 1, 'ctrl', 1, 'GLT'),
#  (718, Decimal('0.401'), Decimal('4.0775'), 1, 'ctrl', 1, 'GLT'),
#  (719, Decimal('0.3258'), Decimal('4.0294'), 1, 'ctrl', 1, 'GLT'),
# ...
#  (761, Decimal('0.1933'), Decimal('2.4082'), 1, 'ctrl', 1, 'GLT'),
#  (762, Decimal('0.2112'), Decimal('2.742'), 1, 'ctrl', 1, 'GLT'),
#  (763, Decimal('0.2721'), Decimal('3.3679'), 1, 'ctrl', 1, 'GLT'),
#  (764, Decimal('0.1361'), Decimal('1.955'), 1, 'ctrl', 1, 'GLT'),
#  (765, Decimal('0.358'), Decimal('4.1726'), 1, 'ctrl', 1, 'GLT'),
#  (766, Decimal('0.3724'), Decimal('4.3276'), 1, 'ctrl', 1, 'GLT'),
#  (767, Decimal('0.0859'), Decimal('1.7406'), 1, 'ctrl', 1, 'GLT'),
#  (768, Decimal('0.512'), Decimal('4.9475'), 1, 'ctrl', 1, 'GLT'),
#  (769, Decimal('0.2649'), Decimal('3.3675'), 1, 'ctrl', 1, 'GLT'),
#  (770, Decimal('0.1969'), Decimal('2.6526'), 1, 'ctrl', 1, 'GLT'),
#  (771, Decimal('0.4261'), Decimal('4.1848'), 1, 'ctrl', 1, 'GLT'),
#  (772, Decimal('0.4798'), Decimal('4.8702'), 1, 'ctrl', 1, 'GLT'),
#  (773, Decimal('0.3724'), Decimal('3.7847'), 1, 'ctrl', 1, 'GLT'),
#  (774, Decimal('0.247'), Decimal('3.0341'), 1, 'ctrl', 1, 'GLT'),
#  (775, Decimal('0.469'), Decimal('4.5189'), 1, 'ctrl', 1, 'GLT'),
#  (776, Decimal('0.3616'), Decimal('4.0594'), 1, 'ctrl', 1, 'GLT'),
#  (777, Decimal('0.154'), Decimal('2.0861'), 1, 'ctrl', 1, 'GLT'),
#  (778, Decimal('0.2578'), Decimal('3.3501'), 1, 'ctrl', 1, 'GLT'),
#  (779, Decimal('0.3616'), Decimal('4.1367'), 1, 'ctrl', 1, 'GLT'),
#  (780, Decimal('0.8629'), Decimal('8.118'), 1, 'ctrl', 1, 'GLT'),
#  (781, Decimal('0.1253'), Decimal('1.8122'), 1, 'ctrl', 1, 'GLT'),
#  (782, Decimal('0.6301'), Decimal('6.0678'), 1, 'ctrl', 1, 'GLT'),
#  (783, Decimal('0.5442'), Decimal('5.1384'), 1, 'ctrl', 1, 'GLT'),
#  (784, Decimal('0.2435'), Decimal('3.2129'), 1, 'ctrl', 1, 'GLT'),
#  (785, Decimal('0.58'), Decimal('5.138'), 1, 'ctrl', 1, 'GLT'),
#  (786, Decimal('0.2291'), Decimal('2.8731'), 1, 'ctrl', 1, 'GLT'),
#  (787, Decimal('0.2864'), Decimal('2.7901'), 1, 'ctrl', 1, 'GLT'),
#  (788, Decimal('0.2506'), Decimal('2.9148'), 1, 'ctrl', 1, 'GLT'),
#  (789, Decimal('0.358'), Decimal('4.5299'), 1, 'ctrl', 1, 'GLT'),
#  (790, Decimal('0.0609'), Decimal('1.2458'), 1, 'ctrl', 1, 'GLT'),
#  (791, Decimal('0.1611'), Decimal('2.581'), 1, 'ctrl', 1, 'GLT'),
#  (792, Decimal('0.4189'), Decimal('4.4049'), 1, 'ctrl', 1, 'GLT'),
#  (793, Decimal('0.3187'), Decimal('3.8207'), 1, 'ctrl', 1, 'GLT'),
#  (794, Decimal('0.2685'), Decimal('3.2186'), 1, 'ctrl', 1, 'GLT'),
#  (795, Decimal('0.3043'), Decimal('3.9934'), 1, 'ctrl', 1, 'GLT'),
#  (796, Decimal('0.3974'), Decimal('4.5481'), 1, 'ctrl', 1, 'GLT'),
#  (797, Decimal('0.734'), Decimal('6.4679'), 1, 'ctrl', 1, 'GLT'),
#  (798, Decimal('0.5227'), Decimal('5.1737'), 1, 'ctrl', 1, 'GLT'),
#  (799, Decimal('0.4117'), Decimal('4.6493'), 1, 'ctrl', 1, 'GLT'),
#  (800, Decimal('0.2793'), Decimal('3.4573'), 1, 'ctrl', 1, 'GLT'),
#  (801, Decimal('0.512'), Decimal('5.007'), 1, 'ctrl', 1, 'GLT'),
#  (802, Decimal('0.1504'), Decimal('2.2472'), 1, 'ctrl', 1, 'GLT'),
#  (803, Decimal('0.3115'), Decimal('3.3323'), 1, 'ctrl', 1, 'GLT'),
#  (804, Decimal('0.1683'), Decimal('2.4915'), 1, 'ctrl', 1, 'GLT'),
#  (805, Decimal('0.2041'), Decimal('2.748'), 1, 'ctrl', 1, 'GLT'),
#  (806, Decimal('0.1253'), Decimal('2.0267'), 1, 'ctrl', 1, 'GLT'),
#  (807, Decimal('0.1038'), Decimal('1.5917'), 1, 'ctrl', 1, 'GLT'),
#  (808, Decimal('0.4332'), Decimal('5.2866'), 1, 'ctrl', 1, 'GLT'),
#  (809, Decimal('0.111'), Decimal('1.6095'), 1, 'ctrl', 1, 'GLT'),
#  (810, Decimal('1.2316'), Decimal('9.6854'), 1, 'ctrl', 1, 'GLT'),
#  (811, Decimal('0.3401'), Decimal('3.5172'), 1, 'ctrl', 1, 'GLT'),
#  (812, Decimal('0.1074'), Decimal('1.6629'), 1, 'ctrl', 1, 'GLT'),
#  (813, Decimal('0.0501'), Decimal('1.1086'), 1, 'ctrl', 1, 'GLT'),
#  (814, Decimal('0.068'), Decimal('1.5853'), 1, 'ctrl', 1, 'GLT'),
#  (815, Decimal('0.1182'), Decimal('2.2828'), 1, 'ctrl', 1, 'GLT'),
#  (816, Decimal('0.1432'), Decimal('2.1877'), 1, 'ctrl', 1, 'GLT'),
#  (817, Decimal('0.4726'), Decimal('5.0422'), 1, 'ctrl', 1, 'GLT'),
#  (818, Decimal('0.1683'), Decimal('2.7359'), 1, 'ctrl', 1, 'GLT'),
#  (819, Decimal('0.2864'), Decimal('3.9336'), 1, 'ctrl', 1, 'GLT'),
#  (820, Decimal('0.3079'), Decimal('3.7313'), 1, 'ctrl', 1, 'GLT'),
#  (821, Decimal('0.1003'), Decimal('1.5974'), 1, 'ctrl', 1, 'GLT'),
#  (822, Decimal('0.0859'), Decimal('1.5258'), 1, 'ctrl', 1, 'GLT'),
#  (823, Decimal('0.2936'), Decimal('3.5941'), 1, 'ctrl', 1, 'GLT'),
#  (824, Decimal('0.0501'), Decimal('1.1385'), 1, 'ctrl', 1, 'GLT'),
#  (825, Decimal('0.8808'), Decimal('6.3664'), 1, 'ctrl', 1, 'GLT'),
#  (826, Decimal('0.2435'), Decimal('2.861'), 1, 'ctrl', 1, 'GLT'),
#  (827, Decimal('0.3938'), Decimal('4.0476'), 1, 'ctrl', 1, 'GLT'),
#  (828, Decimal('0.469'), Decimal('5.5548'), 1, 'ctrl', 1, 'GLT'),
#  (829, Decimal('0.7197'), Decimal('6.0978'), 1, 'ctrl', 1, 'GLT'),
#  (830, Decimal('0.3473'), Decimal('3.8445'), 1, 'ctrl', 1, 'GLT'),
#  (831, Decimal('0.8306'), Decimal('7.4386'), 1, 'ctrl', 1, 'GLT'),
#  (832, Decimal('0.6982'), Decimal('5.9489'), 1, 'ctrl', 1, 'GLT'),
#  (833, Decimal('0.4762'), Decimal('4.9948'), 1, 'ctrl', 1, 'GLT'),
#  (834, Decimal('0.7519'), Decimal('6.3421'), 1, 'ctrl', 1, 'GLT'),
#  (835, Decimal('0.3831'), Decimal('4.0415'), 1, 'ctrl', 1, 'GLT'),
#  (836, Decimal('1.2889'), Decimal('9.5907'), 1, 'ctrl', 1, 'GLT'),
#  (837, Decimal('0.2614'), Decimal('3.3558'), 1, 'ctrl', 1, 'GLT'),
#  (838, Decimal('0.4834'), Decimal('4.9831'), 1, 'ctrl', 1, 'GLT'),
#  (839, Decimal('0.9631'), Decimal('8.3802'), 1, 'ctrl', 1, 'GLT'),
#  (840, Decimal('0.5227'), Decimal('5.3468'), 1, 'ctrl', 1, 'GLT'),
#  (841, Decimal('0.3831'), Decimal('4.4284'), 1, 'ctrl', 1, 'GLT'),
#  (842, Decimal('0.648'), Decimal('6.4433'), 1, 'ctrl', 1, 'GLT'),
#  (843, Decimal('0.2363'), Decimal('3.6119'), 1, 'ctrl', 1, 'GLT'),
#  (844, Decimal('0.2721'), Decimal('3.2486'), 1, 'ctrl', 1, 'GLT'),
#  (845, Decimal('0.6122'), Decimal('5.7283'), 1, 'ctrl', 1, 'GLT'),
#  (846, Decimal('0.444'), Decimal('5.1737'), 1, 'ctrl', 1, 'GLT'),
#  (847, Decimal('0.2757'), Decimal('4.148'), 1, 'ctrl', 1, 'GLT'),
#  (848, Decimal('0.3401'), Decimal('3.6418'), 1, 'ctrl', 1, 'GLT'),
#  (849, Decimal('0.8485'), Decimal('8.0407'), 1, 'ctrl', 1, 'GLT'),
#  (850, Decimal('0.8199'), Decimal('7.2424'), 1, 'ctrl', 1, 'GLT'),
#  (851, Decimal('0.4475'), Decimal('4.8516'), 1, 'ctrl', 1, 'GLT'),
#  (852, Decimal('0.58'), Decimal('5.4419'), 1, 'ctrl', 1, 'GLT'),
#  (853, Decimal('0.4189'), Decimal('4.6788'), 1, 'ctrl', 1, 'GLT'),
#  (854, Decimal('0.2005'), Decimal('2.9144'), 1, 'ctrl', 1, 'GLT'),
#  (855, Decimal('0.7447'), Decimal('6.9794'), 1, 'ctrl', 1, 'GLT'),
#  (856, Decimal('0.3867'), Decimal('4.3333'), 1, 'ctrl', 1, 'GLT'),
#  (857, Decimal('0.0895'), Decimal('1.9729'), 1, 'ctrl', 1, 'GLT'),
#  (858, Decimal('0.6301'), Decimal('5.5135'), 1, 'ctrl', 1, 'GLT'),
#  (859, Decimal('0.4261'), Decimal('4.4883'), 1, 'ctrl', 1, 'GLT'),
#  (860, Decimal('0.3652'), Decimal('3.8741'), 1, 'ctrl', 1, 'GLT'),
#  (861, Decimal('0.5048'), Decimal('5.4476'), 1, 'ctrl', 1, 'GLT'),
#  (862, Decimal('0.2614'), Decimal('3.6297'), 1, 'ctrl', 1, 'GLT'),
#  (863, Decimal('0.3222'), Decimal('3.6418'), 1, 'ctrl', 1, 'GLT'),
#  (864, Decimal('0.179'), Decimal('2.3188'), 1, 'ctrl', 1, 'GLT'),
#  (865, Decimal('0.2649'), Decimal('3.1353'), 1, 'ctrl', 1, 'GLT'),
#  (866, Decimal('0.3903'), Decimal('4.5538'), 1, 'ctrl', 1, 'GLT'),
#  (867, Decimal('0.4547'), Decimal('4.5599'), 1, 'ctrl', 1, 'GLT'),
#  (868, Decimal('0.3867'), Decimal('3.7851'), 1, 'ctrl', 1, 'GLT'),
#  (869, Decimal('1.024'), Decimal('8.6128'), 1, 'ctrl', 1, 'GLT'),
#  (870, Decimal('0.7161'), Decimal('7.117'), 1, 'ctrl', 1, 'GLT'),
#  (871, Decimal('0.444'), Decimal('4.6493'), 1, 'ctrl', 1, 'GLT'),
#  (872, Decimal('0.58'), Decimal('5.013'), 1, 'ctrl', 1, 'GLT'),
#  (873, Decimal('0.4475'), Decimal('4.6015'), 1, 'ctrl', 1, 'GLT'),
#  (874, Decimal('0.2685'), Decimal('3.7547'), 1, 'ctrl', 1, 'GLT'),
#  (875, Decimal('0.3724'), Decimal('4.0829'), 1, 'ctrl', 1, 'GLT'),
#  (876, Decimal('0.401'), Decimal('4.3629'), 1, 'ctrl', 1, 'GLT'),
#  (877, Decimal('0.7161'), Decimal('6.4854'), 1, 'ctrl', 1, 'GLT'),
#  (878, Decimal('0.8951'), Decimal('7.4273'), 1, 'ctrl', 1, 'GLT'),
#  (879, Decimal('0.4404'), Decimal('5.0304'), 1, 'ctrl', 1, 'GLT'),
#  (880, Decimal('0.4296'), Decimal('4.8277'), 1, 'ctrl', 1, 'GLT'),
#  (881, Decimal('0.3724'), Decimal('4.5894'), 1, 'ctrl', 1, 'GLT'),
#  (882, Decimal('0.3724'), Decimal('4.1067'), 1, 'ctrl', 1, 'GLT'),
#  (883, Decimal('0.5908'), Decimal('5.698'), 1, 'ctrl', 1, 'GLT'),
#  (884, Decimal('0.469'), Decimal('5.0486'), 1, 'ctrl', 1, 'GLT'),
#  (885, Decimal('0.2291'), Decimal('2.861'), 1, 'ctrl', 1, 'GLT'),
#  (886, Decimal('0.58'), Decimal('5.7162'), 1, 'ctrl', 1, 'GLT'),
#  (887, Decimal('0.469'), Decimal('4.816'), 1, 'ctrl', 1, 'GLT'),
#  (888, Decimal('0.179'), Decimal('2.6821'), 1, 'ctrl', 1, 'GLT'),
#  (889, Decimal('0.3938'), Decimal('4.7027'), 1, 'ctrl', 1, 'GLT'),
#  (890, Decimal('0.3437'), Decimal('3.5763'), 1, 'ctrl', 1, 'GLT'),
#  (891, Decimal('1.3212'), Decimal('9.1735'), 1, 'ctrl', 1, 'GLT'),
#  (892, Decimal('0.4475'), Decimal('4.4227'), 1, 'ctrl', 1, 'GLT'),
#  (893, Decimal('0.2793'), Decimal('3.3675'), 1, 'ctrl', 1, 'GLT'),
#  (894, Decimal('0.1933'), Decimal('2.7238'), 1, 'ctrl', 1, 'GLT'),
#  (895, Decimal('0.6194'), Decimal('6.0379'), 1, 'ctrl', 1, 'GLT'),
#  (896, Decimal('0.6087'), Decimal('5.9667'), 1, 'ctrl', 1, 'GLT'),
#  (897, Decimal('0.154'), Decimal('2.4972'), 1, 'ctrl', 1, 'GLT'),
#  (898, Decimal('0.5335'), Decimal('6.1269'), 1, 'ctrl', 1, 'GLT'),
#  (899, Decimal('0.2542'), Decimal('3.2243'), 1, 'ctrl', 1, 'GLT'),
#  (900, Decimal('0.1898'), Decimal('2.6522'), 1, 'ctrl', 1, 'GLT'),
#  (901, Decimal('0.3831'), Decimal('4.3807'), 1, 'ctrl', 1, 'GLT'),
#  (902, Decimal('0.5693'), Decimal('5.0664'), 1, 'ctrl', 1, 'GLT'),
#  (903, Decimal('0.623'), Decimal('5.9007'), 1, 'ctrl', 1, 'GLT'),
#  (904, Decimal('0.6982'), Decimal('7.1882'), 1, 'ctrl', 1, 'GLT'),
#  (905, Decimal('0.6982'), Decimal('6.1455'), 1, 'ctrl', 1, 'GLT'),
#  (906, Decimal('0.7376'), Decimal('6.3304'), 1, 'ctrl', 1, 'GLT'),
#  (907, Decimal('0.4619'), Decimal('4.8042'), 1, 'ctrl', 1, 'GLT'),
#  (908, Decimal('0.2435'), Decimal('4.1598'), 1, 'ctrl', 1, 'GLT'),
#  (909, Decimal('0.4619'), Decimal('4.7743'), 1, 'ctrl', 1, 'GLT'),
#  (910, Decimal('0.2435'), Decimal('3.427'), 1, 'ctrl', 1, 'GLT'),
#  (911, Decimal('0.3867'), Decimal('4.7982'), 1, 'ctrl', 1, 'GLT'),
#  (912, Decimal('0.7232'), Decimal('6.4433'), 1, 'ctrl', 1, 'GLT'),
#  (913, Decimal('0.2578'), Decimal('3.5164'), 1, 'ctrl', 1, 'GLT'),
#  (914, Decimal('0.512'), Decimal('5.1142'), 1, 'ctrl', 1, 'GLT'),
#  (915, Decimal('0.358'), Decimal('3.7074'), 1, 'ctrl', 1, 'GLT'),
#  (916, Decimal('0.4368'), Decimal('4.9054'), 1, 'ctrl', 1, 'GLT'),
#  (917, Decimal('0.3831'), Decimal('4.5477'), 1, 'ctrl', 1, 'GLT'),
#  (918, Decimal('0.4941'), Decimal('5.376'), 1, 'ctrl', 1, 'GLT'),
#  (919, Decimal('0.3903'), Decimal('3.6002'), 1, 'ctrl', 1, 'GLT'),
#  (920, Decimal('0.4082'), Decimal('4.7205'), 1, 'ctrl', 1, 'GLT'),
#  (921, Decimal('0.5227'), Decimal('6.0675'), 1, 'ctrl', 1, 'GLT'),
#  (922, Decimal('1.2245'), Decimal('8.6844'), 1, 'ctrl', 1, 'GLT'),
#  (923, Decimal('0.5979'), Decimal('6.288'), 1, 'ctrl', 1, 'GLT'),
#  (924, Decimal('0.8414'), Decimal('7.0211'), 1, 'ctrl', 1, 'GLT'),
#  (925, Decimal('1.0992'), Decimal('8.5651'), 1, 'ctrl', 1, 'GLT'),
#  (926, Decimal('0.6015'), Decimal('5.3286'), 1, 'ctrl', 1, 'GLT'),
#  (927, Decimal('0.9023'), Decimal('8.0877'), 1, 'ctrl', 1, 'GLT'),
#  (928, Decimal('0.1396'), Decimal('3.1527'), 1, 'ctrl', 1, 'GLT'),
#  (929, Decimal('0.2864'), Decimal('3.4092'), 1, 'ctrl', 1, 'GLT'),
#  (930, Decimal('0.4117'), Decimal('5.0426'), 1, 'ctrl', 1, 'GLT'),
#  (931, Decimal('0.7519'), Decimal('6.6699'), 1, 'ctrl', 1, 'GLT'),
#  (932, Decimal('1.2281'), Decimal('9.8408'), 1, 'ctrl', 1, 'GLT'),
#  (933, Decimal('0.8629'), Decimal('7.5637'), 1, 'ctrl', 1, 'GLT'),
#  (934, Decimal('0.9488'), Decimal('9.3759'), 1, 'ctrl', 1, 'GLT'),
#  (935, Decimal('0.6266'), Decimal('5.6268'), 1, 'ctrl', 1, 'GLT'),
#  (936, Decimal('0.5478'), Decimal('6.5623'), 1, 'ctrl', 1, 'GLT'),
#  (937, Decimal('0.6946'), Decimal('6.3418'), 1, 'ctrl', 1, 'GLT'),
#  (938, Decimal('0.4511'), Decimal('4.9827'), 1, 'ctrl', 1, 'GLT'),
#  (939, Decimal('0.1289'), Decimal('2.7833'), 1, 'ctrl', 1, 'GLT'),
#  (940, Decimal('0.7877'), Decimal('6.9794'), 1, 'ctrl', 1, 'GLT'),
#  (941, Decimal('0.6445'), Decimal('6.3122'), 1, 'ctrl', 1, 'GLT'),
#  (942, Decimal('0.4189'), Decimal('5.0304'), 1, 'ctrl', 1, 'GLT'),
#  (943, Decimal('0.6445'), Decimal('6.5267'), 1, 'ctrl', 1, 'GLT'),
#  (944, Decimal('0.2828'), Decimal('3.5225'), 1, 'ctrl', 1, 'GLT'),
#  (945, Decimal('0.4117'), Decimal('5.1555'), 1, 'ctrl', 1, 'GLT'),
#  (946, Decimal('0.666'), Decimal('7.0749'), 1, 'ctrl', 1, 'GLT'),
#  (947, Decimal('0.3867'), Decimal('3.9101'), 1, 'ctrl', 1, 'GLT'),
#  (948, Decimal('0.7376'), Decimal('6.2648'), 1, 'ctrl', 1, 'GLT'),
#  (949, Decimal('0.5693'), Decimal('6.0557'), 1, 'ctrl', 1, 'GLT'),
#  (950, Decimal('0.5048'), Decimal('5.1437'), 1, 'ctrl', 1, 'GLT'),
#  (951, Decimal('0.2936'), Decimal('4.0351'), 1, 'ctrl', 1, 'GLT'),
#  (952, Decimal('0.6266'), Decimal('6.2406'), 1, 'ctrl', 1, 'GLT'),
#  (953, Decimal('0.2256'), Decimal('2.831'), 1, 'ctrl', 1, 'GLT'),
#  (954, Decimal('0.5979'), Decimal('5.5609'), 1, 'ctrl', 1, 'GLT'),
#  (955, Decimal('0.333'), Decimal('4.3928'), 1, 'ctrl', 1, 'GLT'),
#  (956, Decimal('0.5048'), Decimal('5.1377'), 1, 'ctrl', 1, 'GLT'),
#  (957, Decimal('0.3401'), Decimal('3.8684'), 1, 'ctrl', 1, 'GLT'),
#  (958, Decimal('0.5585'), Decimal('6.1152'), 1, 'ctrl', 1, 'GLT'),
#  (959, Decimal('0.4762'), Decimal('4.9532'), 1, 'ctrl', 1, 'GLT'),
#  (960, Decimal('0.7948'), Decimal('7.4443'), 1, 'ctrl', 1, 'GLT'),
#  (961, Decimal('0.3509'), Decimal('4.5777'), 1, 'ctrl', 1, 'GLT'),
#  (962, Decimal('0.4475'), Decimal('4.6015'), 1, 'ctrl', 1, 'GLT'),
#  (963, Decimal('0.666'), Decimal('6.7169'), 1, 'ctrl', 1, 'GLT'),
#  (964, Decimal('0.3903'), Decimal('4.6906'), 1, 'ctrl', 1, 'GLT'),
#  (965, Decimal('1.0526'), Decimal('8.714'), 1, 'ctrl', 1, 'GLT'),
#  (966, Decimal('0.5371'), Decimal('6.5623'), 1, 'ctrl', 1, 'GLT'),
#  (967, Decimal('0.648'), Decimal('6.4009'), 1, 'ctrl', 1, 'GLT'),
#  (968, Decimal('0.4368'), Decimal('4.5239'), 1, 'ctrl', 1, 'GLT'),
#  (969, Decimal('0.3294'), Decimal('4.0351'), 1, 'ctrl', 1, 'GLT'),
#  (970, Decimal('0.1898'), Decimal('2.9682'), 1, 'ctrl', 1, 'GLT'),
#  (971, Decimal('0.2435'), Decimal('3.4092'), 1, 'ctrl', 1, 'GLT'),
#  (972, Decimal('0.2148'), Decimal('3.0099'), 1, 'ctrl', 1, 'GLT'),
#  (973, Decimal('0.5371'), Decimal('5.2934'), 1, 'ctrl', 1, 'GLT'),
#  (974, Decimal('1.2925'), Decimal('9.507'), 1, 'ctrl', 1, 'GLT'),
#  (975, Decimal('0.3795'), Decimal('4.3094'), 1, 'ctrl', 1, 'GLT'),
#  (976, Decimal('0.6122'), Decimal('5.5969'), 1, 'ctrl', 1, 'GLT'),
#  (977, Decimal('0.4368'), Decimal('4.3871'), 1, 'ctrl', 1, 'GLT'),
#  (978, Decimal('0.4941'), Decimal('5.257'), 1, 'ctrl', 1, 'GLT'),
#  (979, Decimal('0.6445'), Decimal('5.8053'), 1, 'ctrl', 1, 'GLT'),
#  (980, Decimal('0.4762'), Decimal('5.5908'), 1, 'ctrl', 1, 'GLT'),
#  (981, Decimal('1.0634'), Decimal('8.3506'), 1, 'ctrl', 1, 'GLT'),
#  (982, Decimal('0.4332'), Decimal('4.8221'), 1, 'ctrl', 1, 'GLT'),
#  (983, Decimal('0.444'), Decimal('4.6788'), 1, 'ctrl', 1, 'GLT'),
#  (984, Decimal('0.5514'), Decimal('5.412'), 1, 'ctrl', 1, 'GLT'),
#  (985, Decimal('0.3938'), Decimal('4.8456'), 1, 'ctrl', 1, 'GLT'),
#  (986, Decimal('0.512'), Decimal('5.8826'), 1, 'ctrl', 1, 'GLT'),
#  (987, Decimal('0.7018'), Decimal('6.4251'), 1, 'ctrl', 1, 'GLT'),
#  (988, Decimal('0.3867'), Decimal('4.8573'), 1, 'ctrl', 1, 'GLT'),
#  (989, Decimal('0.3688'), Decimal('5.1077'), 1, 'ctrl', 1, 'GLT'),
#  (990, Decimal('0.5335'), Decimal('5.8708'), 1, 'ctrl', 1, 'GLT'),
#  (991, Decimal('0.7232'), Decimal('6.6877'), 1, 'ctrl', 1, 'GLT'),
#  (992, Decimal('0.401'), Decimal('4.1961'), 1, 'ctrl', 1, 'GLT'),
#  (993, Decimal('0.7805'), Decimal('7.6887'), 1, 'ctrl', 1, 'GLT'),
#  (994, Decimal('0.7376'), Decimal('7.1344'), 1, 'ctrl', 1, 'GLT'),
#  (995, Decimal('0.8772'), Decimal('7.3496'), 1, 'ctrl', 1, 'GLT'),
#  (996, Decimal('0.4654'), Decimal('4.9115'), 1, 'ctrl', 1, 'GLT'),
#  (997, Decimal('1.024'), Decimal('8.7973'), 1, 'ctrl', 1, 'GLT'),
#  (998, Decimal('0.4261'), Decimal('4.8399'), 1, 'ctrl', 1, 'GLT'),
#  (999, Decimal('0.4905'), Decimal('5.1794'), 1, 'ctrl', 1, 'GLT'),
#  ...]

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Work\GitHub\python_DB_creating\Untitled-1.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000018?line=0'>1</a> conn.close()
#
# AttributeError: 'Engine' object has no attribute 'close'

# %%
sql_df = pd.read_sql(
    "SELECT * FROM GFAP",
    con=conn
)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# UndefinedTable: ОШИБКА:  отношение "gfap" не существует
# LINE 1: SELECT * FROM GFAP
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# e:\Work\GitHub\python_DB_creating\Untitled-1.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000016?line=0'>1</a> sql_df = pd.read_sql(
#       <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000016?line=1'>2</a>     "SELECT * FROM GFAP",
#       <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000016?line=2'>3</a>     con=conn
#       <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000016?line=3'>4</a> )
#       <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000016?line=4'>5</a> conn.execute("SELECT * FROM GFAP").fetchall()
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\pandas\io\sql.py:521, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=511'>512</a>     return pandas_sql.read_table(
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=512'>513</a>         sql,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=513'>514</a>         index_col=index_col,
#    (...)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=517'>518</a>         chunksize=chunksize,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=518'>519</a>     )
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=519'>520</a> else:
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=520'>521</a>     return pandas_sql.read_query(
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=521'>522</a>         sql,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=522'>523</a>         index_col=index_col,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=523'>524</a>         params=params,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=524'>525</a>         coerce_float=coerce_float,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=525'>526</a>         parse_dates=parse_dates,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=526'>527</a>         chunksize=chunksize,
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=527'>528</a>     )
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\pandas\io\sql.py:1308, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1264'>1265</a> """
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1265'>1266</a> Read SQL query into a DataFrame.
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1266'>1267</a>
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1303'>1304</a>
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1304'>1305</a> """
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1305'>1306</a> args = _convert_params(sql, params)
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1307'>1308</a> result = self.execute(*args)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1308'>1309</a> columns = result.keys()
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1310'>1311</a> if chunksize is not None:
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\pandas\io\sql.py:1176, in SQLDatabase.execute(self, *args, **kwargs)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1173'>1174</a> def execute(self, *args, **kwargs):
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1174'>1175</a>     """Simple passthrough to SQLAlchemy connectable"""
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/pandas/io/sql.py?line=1175'>1176</a>     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=398'>399</a> if not skip_warning:
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=399'>400</a>     _warn_with_version(message, version, wtype, stacklevel=3)
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=400'>401</a> return fn(*args, **kwargs)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:3152, in Engine.execute(self, statement, *multiparams, **params)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3133'>3134</a> """Executes the given construct and returns a
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3134'>3135</a> :class:`_engine.CursorResult`.
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3135'>3136</a>
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3148'>3149</a>
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3149'>3150</a> """
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3150'>3151</a> connection = self.connect(close_with_result=True)
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3151'>3152</a> return connection.execute(statement, *multiparams, **params)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1280, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1270'>1271</a> if isinstance(statement, util.string_types):
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1271'>1272</a>     util.warn_deprecated_20(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1272'>1273</a>         "Passing a string to Connection.execute() is "
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1273'>1274</a>         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1276'>1277</a>         "driver-level SQL string."
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1277'>1278</a>     )
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1279'>1280</a>     return self._exec_driver_sql(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1280'>1281</a>         statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1281'>1282</a>         multiparams,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1282'>1283</a>         params,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1283'>1284</a>         _EMPTY_EXECUTION_OPTS,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1284'>1285</a>         future=False,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1285'>1286</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1287'>1288</a> try:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1288'>1289</a>     meth = statement._execute_on_connection
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1584, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1573'>1574</a>         (
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1574'>1575</a>             statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1575'>1576</a>             distilled_params,
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1579'>1580</a>             statement, distilled_parameters, execution_options
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1580'>1581</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1582'>1583</a> dialect = self.dialect
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1583'>1584</a> ret = self._execute_context(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1584'>1585</a>     dialect,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1585'>1586</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1586'>1587</a>     statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1587'>1588</a>     distilled_parameters,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1588'>1589</a>     execution_options,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1589'>1590</a>     statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1590'>1591</a>     distilled_parameters,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1591'>1592</a> )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1593'>1594</a> if not future:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1594'>1595</a>     if self._has_events or self.engine._has_events:
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1847'>1848</a>             branched.close()
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1849'>1850</a> except BaseException as e:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1850'>1851</a>     self._handle_dbapi_exception(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1851'>1852</a>         e, statement, parameters, cursor, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1852'>1853</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1854'>1855</a> return result
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2030'>2031</a> elif should_wrap:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a>     util.raise_(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2033'>2034</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2034'>2035</a> else:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2035'>2036</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a>                 break
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1812'>1813</a>     self.dispatch.after_cursor_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1813'>1814</a>         self,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1814'>1815</a>         cursor,
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         context.executemany,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>     )
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) ОШИБКА:  отношение "gfap" не существует
# LINE 1: SELECT * FROM GFAP
#                       ^
#
# [SQL: SELECT * FROM GFAP]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Work\GitHub\python_DB_creating\Untitled-1.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000015?line=0'>1</a> conn.close()
#
# AttributeError: 'Engine' object has no attribute 'close'

# %%
conn.execute("SELECT * FROM GFAP").fetchall()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# UndefinedTable: ОШИБКА:  отношение "gfap" не существует
# LINE 1: SELECT * FROM GFAP
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# e:\Work\GitHub\python_DB_creating\Untitled-1.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Work/GitHub/python_DB_creating/Untitled-1.ipynb#ch0000014?line=0'>1</a> conn.execute("SELECT * FROM GFAP").fetchall()
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=398'>399</a> if not skip_warning:
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=399'>400</a>     _warn_with_version(message, version, wtype, stacklevel=3)
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/deprecations.py?line=400'>401</a> return fn(*args, **kwargs)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:3152, in Engine.execute(self, statement, *multiparams, **params)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3133'>3134</a> """Executes the given construct and returns a
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3134'>3135</a> :class:`_engine.CursorResult`.
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3135'>3136</a>
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3148'>3149</a>
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3149'>3150</a> """
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3150'>3151</a> connection = self.connect(close_with_result=True)
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=3151'>3152</a> return connection.execute(statement, *multiparams, **params)
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1280, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1270'>1271</a> if isinstance(statement, util.string_types):
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1271'>1272</a>     util.warn_deprecated_20(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1272'>1273</a>         "Passing a string to Connection.execute() is "
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1273'>1274</a>         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1276'>1277</a>         "driver-level SQL string."
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1277'>1278</a>     )
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1279'>1280</a>     return self._exec_driver_sql(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1280'>1281</a>         statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1281'>1282</a>         multiparams,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1282'>1283</a>         params,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1283'>1284</a>         _EMPTY_EXECUTION_OPTS,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1284'>1285</a>         future=False,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1285'>1286</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1287'>1288</a> try:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1288'>1289</a>     meth = statement._execute_on_connection
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1584, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1573'>1574</a>         (
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1574'>1575</a>             statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1575'>1576</a>             distilled_params,
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1579'>1580</a>             statement, distilled_parameters, execution_options
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1580'>1581</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1582'>1583</a> dialect = self.dialect
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1583'>1584</a> ret = self._execute_context(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1584'>1585</a>     dialect,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1585'>1586</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1586'>1587</a>     statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1587'>1588</a>     distilled_parameters,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1588'>1589</a>     execution_options,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1589'>1590</a>     statement,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1590'>1591</a>     distilled_parameters,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1591'>1592</a> )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1593'>1594</a> if not future:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1594'>1595</a>     if self._has_events or self.engine._has_events:
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1847'>1848</a>             branched.close()
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1849'>1850</a> except BaseException as e:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1850'>1851</a>     self._handle_dbapi_exception(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1851'>1852</a>         e, statement, parameters, cursor, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1852'>1853</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1854'>1855</a> return result
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2030'>2031</a> elif should_wrap:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a>     util.raise_(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2033'>2034</a>     )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2034'>2035</a> else:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=2035'>2036</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1805'>1806</a>                 break
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1806'>1807</a>     if not evt_handled:
# -> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1807'>1808</a>         self.dialect.do_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1808'>1809</a>             cursor, statement, parameters, context
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1809'>1810</a>         )
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1811'>1812</a> if self._has_events or self.engine._has_events:
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1812'>1813</a>     self.dispatch.after_cursor_execute(
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1813'>1814</a>         self,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1814'>1815</a>         cursor,
#    (...)
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         context.executemany,
#    <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>     )
#
# File D:\Programs\Anaconda\envs\updatable_db\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///d%3A/Programs/Anaconda/envs/updatable_db/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) ОШИБКА:  отношение "gfap" не существует
# LINE 1: SELECT * FROM GFAP
#                       ^
#
# [SQL: SELECT * FROM GFAP]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# Open a cursor to perform database operations

# %%
cur = conn.cursor()
